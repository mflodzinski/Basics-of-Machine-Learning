# %% [markdown]
# # <center> WSI Ćwiczenie nr.5 - Implementacja drzew decyzyjncyh tworzonych algorytmem ID3</center>
#
# ### <center>Maciej Łodziński, Adam Wróblewski</center>
#
#
# ### Cel eksperymentów:
# Celem ćwiczenia jest implementacja perceptronu wielowarstwowego oraz wybranego algorytmu optymalizacji gradientowej z algorytmem propagacji wstecznej, a następnie wytrenowanie perceptron wielowarstwowy do klasyfikacji zbioru danych MNIST.

# %%
#import libraries
import pandas as pd
import numpy as np
import math
from random import uniform
from sklearn.model_selection import train_test_split
import warnings
from keras.datasets import mnist

warnings.filterwarnings('ignore')

# %%
def one_hot_encode(expected_outputs):
    data_size = expected_outputs.shape[0]
    labels = np.zeros((data_size, 10))
    for row in range(data_size):
        val = expected_outputs[row]
        labels[row, val] = 1
    return labels

def split_to_batches(data, mini_batch_size):
    mini_batches = []
    i = 0
    while i < data.shape[0] - mini_batch_size:
        mini_batch = data[i:(mini_batch_size+i)]
        mini_batches.append(mini_batch)
        i += mini_batch_size
        
    mini_batch = data[i::, :]
    mini_batches.append(mini_batch)
    return mini_batches

def modify_data(data, mini_batch_size):
    batches = split_to_batches(data, mini_batch_size)
    training_batches = []
    for mini_batches in batches:
        x_train = mini_batches[:, 1::]
        y_train = mini_batches[:, 0]
        y_train = one_hot_encode(y_train)
        batch = (x_train, y_train)
        training_batches.append(batch)
    return training_batches

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
train_x_reshaped = x_train.reshape(60000,784)
test_x_reshaped = x_test.reshape(10000,784)
train_y_reshaped = y_train.reshape(-1,1)
test_y_reshaped = y_test.reshape(-1,1)
train_data = np.hstack((train_y_reshaped, train_x_reshaped))
test_data = np.hstack((test_y_reshaped, test_x_reshaped))
train_data = np.vstack((train_data, test_data))

# %%
training_data, validation_data = train_test_split(train_data, train_size=0.9)

X_train = training_data[:, 1::]
Y_train = one_hot_encode(training_data[:, 0])

X_valid = validation_data[:, 1::]
Y_valid = one_hot_encode(validation_data[:, 0])

# %%
class Layer:
    def __init__(self, num_nodes_in : int, num_nodes_out : int) -> None:
        self.num_nodes_in = num_nodes_in
        self.num_nodes_out = num_nodes_out
        
        self.weights = np.random.uniform(-1, 1, (num_nodes_in, num_nodes_out))
        self.cost_gradient_w = np.zeros((num_nodes_in, num_nodes_out))
        
        self.biases = np.zeros((1, num_nodes_out))
        self.cost_gradient_b = np.zeros((1, num_nodes_out))
        
        self.weighted_input = None
        self.activations = None
        self.inputs = None
                        
    # calculates activations of a layer based on input
    def calculate_output(self, inputs) -> list[float]:
        weighted_input = np.matmul(inputs, self.weights)
        activations = sigmoid(weighted_input)
        self.inputs = inputs
        self.weighted_input = weighted_input
        self.activations = activations
        return activations
    
    # 'loop over' weights and biases to subtract corresponding value from gradients arrays
    def apply_gradients(self, learn_rate) -> None:
        self.weights -= self.cost_gradient_w * learn_rate
        self.biases -= self.cost_gradient_b * learn_rate
           
    # calculates some derivatives for output layer
    def calculate_output_layer_node_values(self, expected_output) -> list[float]:
        derivative_cost = cost_derivative(self.activations, expected_output)
        derivative_sigmoid = sigmoid_derivative(self.weighted_input)
        node_values = derivative_sigmoid * derivative_cost
        return node_values
    
    # calculates some derivatives for hidden layers
    def calculate_hidden_layer_node_values(self, old_layer, old_node_values) -> list[float]:
        old_node_values = old_node_values.reshape(-1, 1)
        node_values = np.matmul(old_layer.weights, old_node_values)
        node_values = node_values.reshape(1, -1)
        activate_derivative = sigmoid_derivative(self.weighted_input)
        node_values = node_values * activate_derivative
        return node_values
    
    # updates gradients arrays in layer object based on given node_values, which were calculated in previous methods
    def update_gradients(self, node_values) -> None:
        self.cost_gradient_b += 1 * node_values
        inputs = self.inputs.reshape(-1, 1)
        derivative_cost_wrt_weight = np.matmul(inputs, node_values)
        self.cost_gradient_w += derivative_cost_wrt_weight

# %%
class NeuralNetwork:
    def __init__(self, layer_sizes) -> None:
        self.layers = []
        for i in range(len(layer_sizes) - 1):
            layer = Layer(layer_sizes[i], layer_sizes[i + 1])
            self.layers.append(layer) 
            
    # calls calculate_output function threw all layers
    def forward_propagation(self, inputs) -> list[float]:
        for layer in self.layers:
            inputs = layer.calculate_output(inputs)
        return inputs
    
    # perform apply_gradients on all layers
    def apply_all_gradients(self, learn_rate) -> None:
        for layer in self.layers:
            layer.apply_gradients(learn_rate)
    
    # chooses network's weights and parameters
    def back_propagation(self, inputs, expected_output) -> None:
        self.forward_propagation(inputs)
        
        output_layer = self.layers[-1]
        node_values = output_layer.calculate_output_layer_node_values(expected_output)
        output_layer.update_gradients(node_values)
        
        for index in reversed(range(len(self.layers) - 1)):
            hidden_layer = self.layers[index]
            node_values = hidden_layer.calculate_hidden_layer_node_values(self.layers[index + 1], node_values)
            hidden_layer.update_gradients(node_values)
            
    # clears gradients arrays in layers objects
    def clear_all_gradients(self) -> None:
        for layer in self.layers:
            layer.cost_gradient_w = np.zeros((layer.num_nodes_in, layer.num_nodes_out))
            layer.cost_gradient_b = np.zeros((1, layer.num_nodes_out))
            
    # learns network's weights and biases
    def learn(self, training_batches, learn_rate, batch_size) -> None:
        for batch in training_batches:
            inputs, expected_output = batch
            for i in range(len(expected_output)):
                self.back_propagation(inputs[i].reshape(1 , -1), expected_output[i])
            self.apply_all_gradients(learn_rate / inputs.shape[0])
            self.clear_all_gradients()
              
    # learn function with epochs and progress vizualization
    def learn_with_epochs(self, training_data, learn_rate, batch_size, epochs) -> None:
        training_batches = modify_data(training_data, batch_size)
        for i in range(epochs):
            self.learn(training_batches, learn_rate, batch_size)
            
            results_train = self.clasify(X_train)
            accuracy_train = acuracy(results_train, Y_train)
            cost_train = self.total_cost(X_train, Y_train)
            
            results_valid = self.clasify(X_valid)
            accuracy_valid = acuracy(results_valid, Y_valid)
            cost_valid = self.total_cost(X_valid, Y_valid)
            
            info = f"Epoch {i+1}/{epochs}:\n\
            train set accuracy {round(accuracy_train * 100, 2)}%\n\
            cost train {round(cost_train, 2)}\n\
            valid set accuracy {round(accuracy_valid * 100, 2)}%\n\
            cost valid {round(cost_valid, 2)}\n"
            
            print(info)

    # perform forward_propagation and returns index of node with max value
    def clasify(self, data) -> list[int]:
        ans = []
        for row in range(data.shape[0]):
            output = self.forward_propagation(data[row])
            max_value = max(output)
            index = np.where(output == max_value)
            ans.append(index[0][0].item())
        return np.asarray(ans)
    
    # perform forward_propagation and returns error cost of all final nodes
    def sample_cost(self, inputs, expected_output) -> float:
        output = self.forward_propagation(inputs)
        return cost(output, expected_output)
    
    # perform sample_cost on all data samples
    def total_cost(self, data, expected_outputs) -> float:
        total_cost = 0.0
        size = len(data)
        for i in range(size):
            total_cost += self.sample_cost(data[i], expected_outputs[i])
        return total_cost / size

# %%
def sigmoid(z) -> list[float]:
    return 1 / (1 + np.exp(-z))

def sigmoid_derivative(z) -> list[float]:
    activation = sigmoid(z)
    return activation * (1 - activation)

# %%
def cost(output_activation, expected_output) -> list[float]:
    error = expected_output - output_activation
    return sum(error * error)

def cost_derivative(output_activation, expected_output) -> list[float]:
    return 2 * (output_activation - expected_output)

# %%
def acuracy(outputs, labels) -> float:
    diff = one_hot_encode(outputs) - labels
    wrong = 0
    for result in diff:
        if np.count_nonzero(result) != 0:
            wrong += 1
    accuracy = (len(labels) - wrong ) / len(labels)
    return accuracy

# %%
network = NeuralNetwork([784, 100, 20, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 37.71%
#             cost train 0.79
#             valid set accuracy 36.78%
#             cost valid 0.79
#
# Epoch 2/40:
#             train set accuracy 55.55%
#             cost train 0.64
#             valid set accuracy 54.77%
#             cost valid 0.65
#
# Epoch 3/40:
#             train set accuracy 65.08%
#             cost train 0.54
#             valid set accuracy 64.28%
#             cost valid 0.55
#
# Epoch 4/40:
#             train set accuracy 71.06%
#             cost train 0.47
#             valid set accuracy 70.44%
#             cost valid 0.47
#
# Epoch 5/40:
#             train set accuracy 74.76%
#             cost train 0.42
#             valid set accuracy 74.75%
#             cost valid 0.42
#
# Epoch 6/40:
#             train set accuracy 77.68%
#             cost train 0.38
#             valid set accuracy 77.48%
#             cost valid 0.38
#
# Epoch 7/40:
#             train set accuracy 79.81%
#             cost train 0.35
#             valid set accuracy 79.48%
#             cost valid 0.35
#
# Epoch 8/40:
#             train set accuracy 81.25%
#             cost train 0.32
#             valid set accuracy 80.71%
#             cost valid 0.33
#
# Epoch 9/40:
#             train set accuracy 82.68%
#             cost train 0.3
#             valid set accuracy 82.62%
#             cost valid 0.3
#
# Epoch 10/40:
#             train set accuracy 83.54%
#             cost train 0.28
#             valid set accuracy 83.43%
#             cost valid 0.28
#
# Epoch 11/40:
#             train set accuracy 83.94%
#             cost train 0.27
#             valid set accuracy 83.85%
#             cost valid 0.27
#
# Epoch 12/40:
#             train set accuracy 84.74%
#             cost train 0.26
#             valid set accuracy 85.0%
#             cost valid 0.26
#
# Epoch 13/40:
#             train set accuracy 85.04%
#             cost train 0.25
#             valid set accuracy 85.22%
#             cost valid 0.25
#
# Epoch 14/40:
#             train set accuracy 85.68%
#             cost train 0.24
#             valid set accuracy 85.41%
#             cost valid 0.24
#
# Epoch 15/40:
#             train set accuracy 86.16%
#             cost train 0.23
#             valid set accuracy 85.79%
#             cost valid 0.24
#
# Epoch 16/40:
#             train set accuracy 86.39%
#             cost train 0.23
#             valid set accuracy 85.59%
#             cost valid 0.23
#
# Epoch 17/40:
#             train set accuracy 86.48%
#             cost train 0.23
#             valid set accuracy 86.17%
#             cost valid 0.23
#
# Epoch 18/40:
#             train set accuracy 86.64%
#             cost train 0.22
#             valid set accuracy 86.09%
#             cost valid 0.22
#
# Epoch 19/40:
#             train set accuracy 86.52%
#             cost train 0.22
#             valid set accuracy 86.47%
#             cost valid 0.22
#
# Epoch 20/40:
#             train set accuracy 86.76%
#             cost train 0.22
#             valid set accuracy 86.62%
#             cost valid 0.22
#
# Epoch 21/40:
#             train set accuracy 87.31%
#             cost train 0.21
#             valid set accuracy 87.19%
#             cost valid 0.21
#
# Epoch 22/40:
#             train set accuracy 88.1%
#             cost train 0.2
#             valid set accuracy 87.97%
#             cost valid 0.2
#
# Epoch 23/40:
#             train set accuracy 87.94%
#             cost train 0.2
#             valid set accuracy 87.85%
#             cost valid 0.2
#
# Epoch 24/40:
#             train set accuracy 88.36%
#             cost train 0.19
#             valid set accuracy 88.23%
#             cost valid 0.19
#
# Epoch 25/40:
#             train set accuracy 88.59%
#             cost train 0.19
#             valid set accuracy 88.31%
#             cost valid 0.19
#
# Epoch 26/40:
#             train set accuracy 88.64%
#             cost train 0.19
#             valid set accuracy 88.59%
#             cost valid 0.19
#
# Epoch 27/40:
#             train set accuracy 88.99%
#             cost train 0.18
#             valid set accuracy 88.86%
#             cost valid 0.18
#
# Epoch 28/40:
#             train set accuracy 89.06%
#             cost train 0.18
#             valid set accuracy 88.95%
#             cost valid 0.18
#
# Epoch 29/40:
#             train set accuracy 89.19%
#             cost train 0.18
#             valid set accuracy 88.83%
#             cost valid 0.18
#
# Epoch 30/40:
#             train set accuracy 88.9%
#             cost train 0.18
#             valid set accuracy 88.5%
#             cost valid 0.19
#
# Epoch 31/40:
#             train set accuracy 89.52%
#             cost train 0.17
#             valid set accuracy 89.29%
#             cost valid 0.18
#
# Epoch 32/40:
#             train set accuracy 89.62%
#             cost train 0.17
#             valid set accuracy 89.63%
#             cost valid 0.17
#
# Epoch 33/40:
#             train set accuracy 89.7%
#             cost train 0.17
#             valid set accuracy 89.42%
#             cost valid 0.17
#
# Epoch 34/40:
#             train set accuracy 89.48%
#             cost train 0.17
#             valid set accuracy 89.05%
#             cost valid 0.18
#
# Epoch 35/40:
#             train set accuracy 89.82%
#             cost train 0.17
#             valid set accuracy 89.18%
#             cost valid 0.17
#
# Epoch 36/40:
#             train set accuracy 89.72%
#             cost train 0.17
#             valid set accuracy 89.58%
#             cost valid 0.17
#
# Epoch 37/40:
#             train set accuracy 89.79%
#             cost train 0.17
#             valid set accuracy 89.43%
#             cost valid 0.17
#
# Epoch 38/40:
#             train set accuracy 89.69%
#             cost train 0.17
#             valid set accuracy 89.27%
#             cost valid 0.17
#
# Epoch 39/40:
#             train set accuracy 89.93%
#             cost train 0.16
#             valid set accuracy 89.72%
#             cost valid 0.16
#
# Epoch 40/40:
#             train set accuracy 90.07%
#             cost train 0.16
#             valid set accuracy 89.62%
#             cost valid 0.16

# %%
network = NeuralNetwork([784, 16, 16, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 20.36%
#             cost train 0.86
#             valid set accuracy 20.42%
#             cost valid 0.86
#
# Epoch 2/40:
#             train set accuracy 31.61%
#             cost train 0.81
#             valid set accuracy 31.31%
#             cost valid 0.81
#
# Epoch 3/40:
#             train set accuracy 42.24%
#             cost train 0.76
#             valid set accuracy 42.18%
#             cost valid 0.76
#
# Epoch 4/40:
#             train set accuracy 52.94%
#             cost train 0.69
#             valid set accuracy 52.48%
#             cost valid 0.69
#
# Epoch 5/40:
#             train set accuracy 58.54%
#             cost train 0.62
#             valid set accuracy 57.98%
#             cost valid 0.62
#
# Epoch 6/40:
#             train set accuracy 61.78%
#             cost train 0.56
#             valid set accuracy 61.69%
#             cost valid 0.57
#
# Epoch 7/40:
#             train set accuracy 67.15%
#             cost train 0.51
#             valid set accuracy 67.11%
#             cost valid 0.51
#
# Epoch 8/40:
#             train set accuracy 67.84%
#             cost train 0.49
#             valid set accuracy 67.97%
#             cost valid 0.49
#
# Epoch 9/40:
#             train set accuracy 69.66%
#             cost train 0.47
#             valid set accuracy 69.21%
#             cost valid 0.47
#
# Epoch 10/40:
#             train set accuracy 71.57%
#             cost train 0.45
#             valid set accuracy 71.63%
#             cost valid 0.44
#
# Epoch 11/40:
#             train set accuracy 74.98%
#             cost train 0.41
#             valid set accuracy 75.23%
#             cost valid 0.41
#
# Epoch 12/40:
#             train set accuracy 76.58%
#             cost train 0.38
#             valid set accuracy 76.63%
#             cost valid 0.38
#
# Epoch 13/40:
#             train set accuracy 76.73%
#             cost train 0.37
#             valid set accuracy 76.77%
#             cost valid 0.37
#
# Epoch 14/40:
#             train set accuracy 76.64%
#             cost train 0.37
#             valid set accuracy 76.74%
#             cost valid 0.36
#
# Epoch 15/40:
#             train set accuracy 78.55%
#             cost train 0.34
#             valid set accuracy 78.73%
#             cost valid 0.34
#
# Epoch 16/40:
#             train set accuracy 77.3%
#             cost train 0.35
#             valid set accuracy 77.39%
#             cost valid 0.35
#
# Epoch 17/40:
#             train set accuracy 78.14%
#             cost train 0.34
#             valid set accuracy 78.01%
#             cost valid 0.34
#
# Epoch 18/40:
#             train set accuracy 76.79%
#             cost train 0.35
#             valid set accuracy 76.89%
#             cost valid 0.35
#
# Epoch 19/40:
#             train set accuracy 79.83%
#             cost train 0.33
#             valid set accuracy 79.42%
#             cost valid 0.33
#
# Epoch 20/40:
#             train set accuracy 80.83%
#             cost train 0.31
#             valid set accuracy 80.61%
#             cost valid 0.31
#
# Epoch 21/40:
#             train set accuracy 80.47%
#             cost train 0.32
#             valid set accuracy 80.31%
#             cost valid 0.32
#
# Epoch 22/40:
#             train set accuracy 78.26%
#             cost train 0.34
#             valid set accuracy 78.27%
#             cost valid 0.34
#
# Epoch 23/40:
#             train set accuracy 80.81%
#             cost train 0.31
#             valid set accuracy 80.75%
#             cost valid 0.31
#
# Epoch 24/40:
#             train set accuracy 75.22%
#             cost train 0.36
#             valid set accuracy 74.92%
#             cost valid 0.36
#
# Epoch 25/40:
#             train set accuracy 76.96%
#             cost train 0.34
#             valid set accuracy 76.94%
#             cost valid 0.34
#
# Epoch 26/40:
#             train set accuracy 78.06%
#             cost train 0.32
#             valid set accuracy 78.28%
#             cost valid 0.32
#
# Epoch 27/40:
#             train set accuracy 83.42%
#             cost train 0.27
#             valid set accuracy 83.43%
#             cost valid 0.27
#
# Epoch 28/40:
#             train set accuracy 82.47%
#             cost train 0.27
#             valid set accuracy 82.81%
#             cost valid 0.27
#
# Epoch 29/40:
#             train set accuracy 82.99%
#             cost train 0.27
#             valid set accuracy 82.68%
#             cost valid 0.27
#
# Epoch 30/40:
#             train set accuracy 81.92%
#             cost train 0.28
#             valid set accuracy 81.58%
#             cost valid 0.28
#
# Epoch 31/40:
#             train set accuracy 82.64%
#             cost train 0.28
#             valid set accuracy 82.89%
#             cost valid 0.27
#
# Epoch 32/40:
#             train set accuracy 84.27%
#             cost train 0.25
#             valid set accuracy 84.31%
#             cost valid 0.25
#
# Epoch 33/40:
#             train set accuracy 81.69%
#             cost train 0.29
#             valid set accuracy 81.2%
#             cost valid 0.29
#
# Epoch 34/40:
#             train set accuracy 84.23%
#             cost train 0.25
#             valid set accuracy 84.33%
#             cost valid 0.25
#
# Epoch 35/40:
#             train set accuracy 82.66%
#             cost train 0.27
#             valid set accuracy 82.67%
#             cost valid 0.27
#
# Epoch 36/40:
#             train set accuracy 82.98%
#             cost train 0.26
#             valid set accuracy 83.35%
#             cost valid 0.25
#
# Epoch 37/40:
#             train set accuracy 84.54%
#             cost train 0.25
#             valid set accuracy 84.87%
#             cost valid 0.25
#
# Epoch 38/40:
#             train set accuracy 83.75%
#             cost train 0.25
#             valid set accuracy 84.1%
#             cost valid 0.25
#
# Epoch 39/40:
#             train set accuracy 84.18%
#             cost train 0.25
#             valid set accuracy 84.08%
#             cost valid 0.25
#
# Epoch 40/40:
#             train set accuracy 83.32%
#             cost train 0.25
#             valid set accuracy 83.47%
#             cost valid 0.25

# %%
network = NeuralNetwork([784, 10, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 30.05%
#             cost train 0.86
#             valid set accuracy 30.17%
#             cost valid 0.86
#
# Epoch 2/40:
#             train set accuracy 36.78%
#             cost train 0.79
#             valid set accuracy 36.73%
#             cost valid 0.79
#
# Epoch 3/40:
#             train set accuracy 43.59%
#             cost train 0.73
#             valid set accuracy 43.52%
#             cost valid 0.73
#
# Epoch 4/40:
#             train set accuracy 48.47%
#             cost train 0.68
#             valid set accuracy 48.28%
#             cost valid 0.68
#
# Epoch 5/40:
#             train set accuracy 52.65%
#             cost train 0.64
#             valid set accuracy 52.96%
#             cost valid 0.64
#
# Epoch 6/40:
#             train set accuracy 55.25%
#             cost train 0.61
#             valid set accuracy 55.47%
#             cost valid 0.61
#
# Epoch 7/40:
#             train set accuracy 58.58%
#             cost train 0.6
#             valid set accuracy 59.3%
#             cost valid 0.59
#
# Epoch 8/40:
#             train set accuracy 62.1%
#             cost train 0.56
#             valid set accuracy 62.26%
#             cost valid 0.56
#
# Epoch 9/40:
#             train set accuracy 58.83%
#             cost train 0.58
#             valid set accuracy 58.98%
#             cost valid 0.58
#
# Epoch 10/40:
#             train set accuracy 66.06%
#             cost train 0.52
#             valid set accuracy 66.67%
#             cost valid 0.52
#
# Epoch 11/40:
#             train set accuracy 66.91%
#             cost train 0.51
#             valid set accuracy 67.43%
#             cost valid 0.51
#
# Epoch 12/40:
#             train set accuracy 68.81%
#             cost train 0.48
#             valid set accuracy 69.85%
#             cost valid 0.47
#
# Epoch 13/40:
#             train set accuracy 69.65%
#             cost train 0.47
#             valid set accuracy 70.82%
#             cost valid 0.46
#
# Epoch 14/40:
#             train set accuracy 71.69%
#             cost train 0.45
#             valid set accuracy 72.27%
#             cost valid 0.44
#
# Epoch 15/40:
#             train set accuracy 73.66%
#             cost train 0.43
#             valid set accuracy 74.29%
#             cost valid 0.42
#
# Epoch 16/40:
#             train set accuracy 71.57%
#             cost train 0.44
#             valid set accuracy 72.77%
#             cost valid 0.43
#
# Epoch 17/40:
#             train set accuracy 73.32%
#             cost train 0.43
#             valid set accuracy 73.52%
#             cost valid 0.42
#
# Epoch 18/40:
#             train set accuracy 75.06%
#             cost train 0.4
#             valid set accuracy 75.72%
#             cost valid 0.39
#
# Epoch 19/40:
#             train set accuracy 69.13%
#             cost train 0.46
#             valid set accuracy 69.45%
#             cost valid 0.46
#
# Epoch 20/40:
#             train set accuracy 75.44%
#             cost train 0.4
#             valid set accuracy 75.88%
#             cost valid 0.39
#
# Epoch 21/40:
#             train set accuracy 76.91%
#             cost train 0.38
#             valid set accuracy 77.55%
#             cost valid 0.37
#
# Epoch 22/40:
#             train set accuracy 77.12%
#             cost train 0.37
#             valid set accuracy 77.6%
#             cost valid 0.37
#
# Epoch 23/40:
#             train set accuracy 75.88%
#             cost train 0.39
#             valid set accuracy 76.4%
#             cost valid 0.38
#
# Epoch 24/40:
#             train set accuracy 74.5%
#             cost train 0.39
#             valid set accuracy 74.74%
#             cost valid 0.38
#
# Epoch 25/40:
#             train set accuracy 72.93%
#             cost train 0.4
#             valid set accuracy 72.91%
#             cost valid 0.4
#
# Epoch 26/40:
#             train set accuracy 79.43%
#             cost train 0.34
#             valid set accuracy 79.94%
#             cost valid 0.33
#
# Epoch 27/40:
#             train set accuracy 79.33%
#             cost train 0.34
#             valid set accuracy 79.7%
#             cost valid 0.33
#
# Epoch 28/40:
#             train set accuracy 78.23%
#             cost train 0.35
#             valid set accuracy 78.28%
#             cost valid 0.35
#
# Epoch 29/40:
#             train set accuracy 78.34%
#             cost train 0.35
#             valid set accuracy 78.2%
#             cost valid 0.36
#
# Epoch 30/40:
#             train set accuracy 78.65%
#             cost train 0.34
#             valid set accuracy 78.92%
#             cost valid 0.33
#
# Epoch 31/40:
#             train set accuracy 79.67%
#             cost train 0.32
#             valid set accuracy 79.93%
#             cost valid 0.32
#
# Epoch 32/40:
#             train set accuracy 79.76%
#             cost train 0.32
#             valid set accuracy 79.78%
#             cost valid 0.32
#
# Epoch 33/40:
#             train set accuracy 79.4%
#             cost train 0.33
#             valid set accuracy 79.65%
#             cost valid 0.32
#
# Epoch 34/40:
#             train set accuracy 80.05%
#             cost train 0.31
#             valid set accuracy 79.97%
#             cost valid 0.32
#
# Epoch 35/40:
#             train set accuracy 79.25%
#             cost train 0.32
#             valid set accuracy 79.45%
#             cost valid 0.32
#
# Epoch 36/40:
#             train set accuracy 80.18%
#             cost train 0.31
#             valid set accuracy 80.05%
#             cost valid 0.31
#
# Epoch 37/40:
#             train set accuracy 81.15%
#             cost train 0.3
#             valid set accuracy 80.84%
#             cost valid 0.3
#
# Epoch 38/40:
#             train set accuracy 81.12%
#             cost train 0.3
#             valid set accuracy 81.08%
#             cost valid 0.3
#
# Epoch 39/40:
#             train set accuracy 76.56%
#             cost train 0.35
#             valid set accuracy 76.51%
#             cost valid 0.35
#
# Epoch 40/40:
#             train set accuracy 79.46%
#             cost train 0.31
#             valid set accuracy 79.47%
#             cost valid 0.31

# %%
network = NeuralNetwork([784, 16, 16, 16, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 20.91%
#             cost train 0.88
#             valid set accuracy 20.94%
#             cost valid 0.88
#
# Epoch 2/40:
#             train set accuracy 24.45%
#             cost train 0.84
#             valid set accuracy 24.4%
#             cost valid 0.84
#
# Epoch 3/40:
#             train set accuracy 27.78%
#             cost train 0.81
#             valid set accuracy 27.59%
#             cost valid 0.81
#
# Epoch 4/40:
#             train set accuracy 32.49%
#             cost train 0.78
#             valid set accuracy 31.98%
#             cost valid 0.78
#
# Epoch 5/40:
#             train set accuracy 34.74%
#             cost train 0.75
#             valid set accuracy 34.72%
#             cost valid 0.75
#
# Epoch 6/40:
#             train set accuracy 39.61%
#             cost train 0.73
#             valid set accuracy 39.38%
#             cost valid 0.73
#
# Epoch 7/40:
#             train set accuracy 42.72%
#             cost train 0.7
#             valid set accuracy 42.58%
#             cost valid 0.7
#
# Epoch 8/40:
#             train set accuracy 45.5%
#             cost train 0.68
#             valid set accuracy 45.34%
#             cost valid 0.68
#
# Epoch 9/40:
#             train set accuracy 48.3%
#             cost train 0.64
#             valid set accuracy 48.39%
#             cost valid 0.64
#
# Epoch 10/40:
#             train set accuracy 53.36%
#             cost train 0.61
#             valid set accuracy 53.68%
#             cost valid 0.62
#
# Epoch 11/40:
#             train set accuracy 56.09%
#             cost train 0.59
#             valid set accuracy 56.43%
#             cost valid 0.59
#
# Epoch 12/40:
#             train set accuracy 58.72%
#             cost train 0.56
#             valid set accuracy 58.83%
#             cost valid 0.56
#
# Epoch 13/40:
#             train set accuracy 61.61%
#             cost train 0.54
#             valid set accuracy 62.14%
#             cost valid 0.54
#
# Epoch 14/40:
#             train set accuracy 66.52%
#             cost train 0.5
#             valid set accuracy 66.92%
#             cost valid 0.5
#
# Epoch 15/40:
#             train set accuracy 68.38%
#             cost train 0.49
#             valid set accuracy 68.91%
#             cost valid 0.49
#
# Epoch 16/40:
#             train set accuracy 70.31%
#             cost train 0.46
#             valid set accuracy 70.23%
#             cost valid 0.46
#
# Epoch 17/40:
#             train set accuracy 69.5%
#             cost train 0.45
#             valid set accuracy 70.0%
#             cost valid 0.45
#
# Epoch 18/40:
#             train set accuracy 71.89%
#             cost train 0.43
#             valid set accuracy 71.76%
#             cost valid 0.43
#
# Epoch 19/40:
#             train set accuracy 74.18%
#             cost train 0.4
#             valid set accuracy 73.69%
#             cost valid 0.4
#
# Epoch 20/40:
#             train set accuracy 71.04%
#             cost train 0.41
#             valid set accuracy 71.13%
#             cost valid 0.41
#
# Epoch 21/40:
#             train set accuracy 74.33%
#             cost train 0.39
#             valid set accuracy 74.24%
#             cost valid 0.4
#
# Epoch 22/40:
#             train set accuracy 74.82%
#             cost train 0.38
#             valid set accuracy 74.57%
#             cost valid 0.38
#
# Epoch 23/40:
#             train set accuracy 78.24%
#             cost train 0.34
#             valid set accuracy 78.05%
#             cost valid 0.34
#
# Epoch 24/40:
#             train set accuracy 73.98%
#             cost train 0.39
#             valid set accuracy 74.02%
#             cost valid 0.39
#
# Epoch 25/40:
#             train set accuracy 76.47%
#             cost train 0.35
#             valid set accuracy 76.45%
#             cost valid 0.35
#
# Epoch 26/40:
#             train set accuracy 74.68%
#             cost train 0.36
#             valid set accuracy 74.68%
#             cost valid 0.36
#
# Epoch 27/40:
#             train set accuracy 76.81%
#             cost train 0.34
#             valid set accuracy 76.66%
#             cost valid 0.35
#
# Epoch 28/40:
#             train set accuracy 79.99%
#             cost train 0.31
#             valid set accuracy 80.0%
#             cost valid 0.31
#
# Epoch 29/40:
#             train set accuracy 78.65%
#             cost train 0.33
#             valid set accuracy 78.12%
#             cost valid 0.33
#
# Epoch 30/40:
#             train set accuracy 80.67%
#             cost train 0.3
#             valid set accuracy 80.44%
#             cost valid 0.3
#
# Epoch 31/40:
#             train set accuracy 80.17%
#             cost train 0.31
#             valid set accuracy 79.98%
#             cost valid 0.31
#
# Epoch 32/40:
#             train set accuracy 77.36%
#             cost train 0.34
#             valid set accuracy 77.1%
#             cost valid 0.34
#
# Epoch 33/40:
#             train set accuracy 82.19%
#             cost train 0.28
#             valid set accuracy 82.17%
#             cost valid 0.28
#
# Epoch 34/40:
#             train set accuracy 78.94%
#             cost train 0.31
#             valid set accuracy 78.85%
#             cost valid 0.32
#
# Epoch 35/40:
#             train set accuracy 81.79%
#             cost train 0.28
#             valid set accuracy 82.31%
#             cost valid 0.27
#
# Epoch 36/40:
#             train set accuracy 82.04%
#             cost train 0.28
#             valid set accuracy 82.38%
#             cost valid 0.28
#
# Epoch 37/40:
#             train set accuracy 80.26%
#             cost train 0.3
#             valid set accuracy 80.38%
#             cost valid 0.29
#
# Epoch 38/40:
#             train set accuracy 79.88%
#             cost train 0.3
#             valid set accuracy 80.15%
#             cost valid 0.3
#
# Epoch 39/40:
#             train set accuracy 80.95%
#             cost train 0.3
#             valid set accuracy 80.97%
#             cost valid 0.29
#
# Epoch 40/40:
#             train set accuracy 80.32%
#             cost train 0.29
#             valid set accuracy 80.46%
#             cost valid 0.29

# %%
network = NeuralNetwork([784, 100, 100, 100, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 55.22%
#             cost train 0.62
#             valid set accuracy 55.15%
#             cost valid 0.62
#
# Epoch 2/40:
#             train set accuracy 71.04%
#             cost train 0.45
#             valid set accuracy 70.88%
#             cost valid 0.46
#
# Epoch 3/40:
#             train set accuracy 76.85%
#             cost train 0.37
#             valid set accuracy 76.9%
#             cost valid 0.37
#
# Epoch 4/40:
#             train set accuracy 79.72%
#             cost train 0.33
#             valid set accuracy 79.54%
#             cost valid 0.33
#
# Epoch 5/40:
#             train set accuracy 81.39%
#             cost train 0.3
#             valid set accuracy 81.44%
#             cost valid 0.3
#
# Epoch 6/40:
#             train set accuracy 82.94%
#             cost train 0.28
#             valid set accuracy 82.98%
#             cost valid 0.28
#
# Epoch 7/40:
#             train set accuracy 83.71%
#             cost train 0.26
#             valid set accuracy 83.99%
#             cost valid 0.26
#
# Epoch 8/40:
#             train set accuracy 84.25%
#             cost train 0.25
#             valid set accuracy 84.16%
#             cost valid 0.25
#
# Epoch 9/40:
#             train set accuracy 85.03%
#             cost train 0.24
#             valid set accuracy 85.01%
#             cost valid 0.24
#
# Epoch 10/40:
#             train set accuracy 85.44%
#             cost train 0.23
#             valid set accuracy 85.42%
#             cost valid 0.23
#
# Epoch 11/40:
#             train set accuracy 86.03%
#             cost train 0.22
#             valid set accuracy 85.76%
#             cost valid 0.23
#
# Epoch 12/40:
#             train set accuracy 86.44%
#             cost train 0.22
#             valid set accuracy 86.11%
#             cost valid 0.22
#
# Epoch 13/40:
#             train set accuracy 86.84%
#             cost train 0.21
#             valid set accuracy 86.54%
#             cost valid 0.21
#
# Epoch 14/40:
#             train set accuracy 87.11%
#             cost train 0.21
#             valid set accuracy 86.69%
#             cost valid 0.21
#
# Epoch 15/40:
#             train set accuracy 87.67%
#             cost train 0.2
#             valid set accuracy 87.21%
#             cost valid 0.2
#
# Epoch 16/40:
#             train set accuracy 87.5%
#             cost train 0.2
#             valid set accuracy 86.98%
#             cost valid 0.2
#
# Epoch 17/40:
#             train set accuracy 88.03%
#             cost train 0.19
#             valid set accuracy 88.05%
#             cost valid 0.19
#
# Epoch 18/40:
#             train set accuracy 88.3%
#             cost train 0.19
#             valid set accuracy 87.94%
#             cost valid 0.19
#
# Epoch 19/40:
#             train set accuracy 88.51%
#             cost train 0.18
#             valid set accuracy 88.36%
#             cost valid 0.18
#
# Epoch 20/40:
#             train set accuracy 88.55%
#             cost train 0.18
#             valid set accuracy 88.22%
#             cost valid 0.18
#
# Epoch 21/40:
#             train set accuracy 88.76%
#             cost train 0.18
#             valid set accuracy 88.67%
#             cost valid 0.18
#
# Epoch 22/40:
#             train set accuracy 88.87%
#             cost train 0.18
#             valid set accuracy 88.56%
#             cost valid 0.18
#
# Epoch 23/40:
#             train set accuracy 88.75%
#             cost train 0.18
#             valid set accuracy 88.55%
#             cost valid 0.18
#
# Epoch 24/40:
#             train set accuracy 89.34%
#             cost train 0.17
#             valid set accuracy 88.76%
#             cost valid 0.18
#
# Epoch 25/40:
#             train set accuracy 89.86%
#             cost train 0.16
#             valid set accuracy 89.61%
#             cost valid 0.17
#
# Epoch 26/40:
#             train set accuracy 89.74%
#             cost train 0.16
#             valid set accuracy 89.42%
#             cost valid 0.17
#
# Epoch 27/40:
#             train set accuracy 89.96%
#             cost train 0.16
#             valid set accuracy 89.82%
#             cost valid 0.16
#
# Epoch 28/40:
#             train set accuracy 90.18%
#             cost train 0.16
#             valid set accuracy 89.38%
#             cost valid 0.16
#
# Epoch 29/40:
#             train set accuracy 90.42%
#             cost train 0.15
#             valid set accuracy 90.12%
#             cost valid 0.16
#
# Epoch 30/40:
#             train set accuracy 90.11%
#             cost train 0.16
#             valid set accuracy 89.57%
#             cost valid 0.16
#
# Epoch 31/40:
#             train set accuracy 90.86%
#             cost train 0.15
#             valid set accuracy 90.44%
#             cost valid 0.15
#
# Epoch 32/40:
#             train set accuracy 90.89%
#             cost train 0.15
#             valid set accuracy 90.67%
#             cost valid 0.15
#
# Epoch 33/40:
#             train set accuracy 90.92%
#             cost train 0.14
#             valid set accuracy 90.99%
#             cost valid 0.15
#
# Epoch 34/40:
#             train set accuracy 90.76%
#             cost train 0.15
#             valid set accuracy 90.65%
#             cost valid 0.15
#
# Epoch 35/40:
#             train set accuracy 90.46%
#             cost train 0.15
#             valid set accuracy 90.18%
#             cost valid 0.16
#
# Epoch 36/40:
#             train set accuracy 90.85%
#             cost train 0.15
#             valid set accuracy 90.33%
#             cost valid 0.15
#
# Epoch 37/40:
#             train set accuracy 90.91%
#             cost train 0.14
#             valid set accuracy 90.56%
#             cost valid 0.15
#
# Epoch 38/40:
#             train set accuracy 91.29%
#             cost train 0.14
#             valid set accuracy 91.02%
#             cost valid 0.14
#
# Epoch 39/40:
#             train set accuracy 91.3%
#             cost train 0.14
#             valid set accuracy 90.94%
#             cost valid 0.14
#
# Epoch 40/40:
#             train set accuracy 91.24%
#             cost train 0.14
#             valid set accuracy 90.72%
#             cost valid 0.15

# %%
network = NeuralNetwork([784, 200, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 21.6%
#             cost train 0.9
#             valid set accuracy 21.98%
#             cost valid 0.89
#
# Epoch 2/40:
#             train set accuracy 29.9%
#             cost train 0.81
#             valid set accuracy 30.26%
#             cost valid 0.8
#
# Epoch 3/40:
#             train set accuracy 31.81%
#             cost train 0.77
#             valid set accuracy 32.61%
#             cost valid 0.76
#
# Epoch 4/40:
#             train set accuracy 32.98%
#             cost train 0.75
#             valid set accuracy 33.77%
#             cost valid 0.75
#
# Epoch 5/40:
#             train set accuracy 39.96%
#             cost train 0.69
#             valid set accuracy 40.62%
#             cost valid 0.69
#
# Epoch 6/40:
#             train set accuracy 41.03%
#             cost train 0.67
#             valid set accuracy 42.0%
#             cost valid 0.66
#
# Epoch 7/40:
#             train set accuracy 42.26%
#             cost train 0.66
#             valid set accuracy 43.2%
#             cost valid 0.66
#
# Epoch 8/40:
#             train set accuracy 46.44%
#             cost train 0.64
#             valid set accuracy 47.19%
#             cost valid 0.64
#
# Epoch 9/40:
#             train set accuracy 49.84%
#             cost train 0.6
#             valid set accuracy 50.71%
#             cost valid 0.59
#
# Epoch 10/40:
#             train set accuracy 50.96%
#             cost train 0.58
#             valid set accuracy 51.7%
#             cost valid 0.58
#
# Epoch 11/40:
#             train set accuracy 51.99%
#             cost train 0.57
#             valid set accuracy 52.74%
#             cost valid 0.56
#
# Epoch 12/40:
#             train set accuracy 52.76%
#             cost train 0.56
#             valid set accuracy 53.54%
#             cost valid 0.55
#
# Epoch 13/40:
#             train set accuracy 53.46%
#             cost train 0.55
#             valid set accuracy 54.33%
#             cost valid 0.54
#
# Epoch 14/40:
#             train set accuracy 53.88%
#             cost train 0.54
#             valid set accuracy 54.74%
#             cost valid 0.54
#
# Epoch 15/40:
#             train set accuracy 54.4%
#             cost train 0.54
#             valid set accuracy 55.37%
#             cost valid 0.53
#
# Epoch 16/40:
#             train set accuracy 55.33%
#             cost train 0.53
#             valid set accuracy 56.37%
#             cost valid 0.53
#
# Epoch 17/40:
#             train set accuracy 60.76%
#             cost train 0.51
#             valid set accuracy 61.51%
#             cost valid 0.5
#
# Epoch 18/40:
#             train set accuracy 63.23%
#             cost train 0.46
#             valid set accuracy 63.73%
#             cost valid 0.46
#
# Epoch 19/40:
#             train set accuracy 65.63%
#             cost train 0.44
#             valid set accuracy 65.98%
#             cost valid 0.44
#
# Epoch 20/40:
#             train set accuracy 69.69%
#             cost train 0.41
#             valid set accuracy 70.14%
#             cost valid 0.4
#
# Epoch 21/40:
#             train set accuracy 71.04%
#             cost train 0.38
#             valid set accuracy 71.73%
#             cost valid 0.38
#
# Epoch 22/40:
#             train set accuracy 71.45%
#             cost train 0.37
#             valid set accuracy 71.47%
#             cost valid 0.37
#
# Epoch 23/40:
#             train set accuracy 71.98%
#             cost train 0.36
#             valid set accuracy 72.34%
#             cost valid 0.36
#
# Epoch 24/40:
#             train set accuracy 72.07%
#             cost train 0.36
#             valid set accuracy 72.52%
#             cost valid 0.36
#
# Epoch 25/40:
#             train set accuracy 72.29%
#             cost train 0.35
#             valid set accuracy 72.88%
#             cost valid 0.35
#
# Epoch 26/40:
#             train set accuracy 72.61%
#             cost train 0.35
#             valid set accuracy 73.03%
#             cost valid 0.35
#
# Epoch 27/40:
#             train set accuracy 72.86%
#             cost train 0.35
#             valid set accuracy 73.21%
#             cost valid 0.34
#
# Epoch 28/40:
#             train set accuracy 73.05%
#             cost train 0.34
#             valid set accuracy 73.46%
#             cost valid 0.34
#
# Epoch 29/40:
#             train set accuracy 73.38%
#             cost train 0.34
#             valid set accuracy 73.44%
#             cost valid 0.34
#
# Epoch 30/40:
#             train set accuracy 73.67%
#             cost train 0.33
#             valid set accuracy 73.8%
#             cost valid 0.33
#
# Epoch 31/40:
#             train set accuracy 73.67%
#             cost train 0.33
#             valid set accuracy 74.11%
#             cost valid 0.33
#
# Epoch 32/40:
#             train set accuracy 74.01%
#             cost train 0.33
#             valid set accuracy 74.49%
#             cost valid 0.33
#
# Epoch 33/40:
#             train set accuracy 74.62%
#             cost train 0.33
#             valid set accuracy 75.06%
#             cost valid 0.33
#
# Epoch 34/40:
#             train set accuracy 79.28%
#             cost train 0.31
#             valid set accuracy 79.38%
#             cost valid 0.31
#
# Epoch 35/40:
#             train set accuracy 81.14%
#             cost train 0.28
#             valid set accuracy 80.97%
#             cost valid 0.29
#
# Epoch 36/40:
#             train set accuracy 81.58%
#             cost train 0.27
#             valid set accuracy 81.58%
#             cost valid 0.28
#
# Epoch 37/40:
#             train set accuracy 82.0%
#             cost train 0.27
#             valid set accuracy 81.62%
#             cost valid 0.27
#
# Epoch 38/40:
#             train set accuracy 82.26%
#             cost train 0.26
#             valid set accuracy 81.99%
#             cost valid 0.26
#
# Epoch 39/40:
#             train set accuracy 82.45%
#             cost train 0.26
#             valid set accuracy 81.84%
#             cost valid 0.26
#
# Epoch 40/40:
#             train set accuracy 82.61%
#             cost train 0.25
#             valid set accuracy 82.2%
#             cost valid 0.26

# %%
network = NeuralNetwork([784, 200, 200, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 42.73%
#             cost train 0.71
#             valid set accuracy 42.61%
#             cost valid 0.72
#
# Epoch 2/40:
#             train set accuracy 63.43%
#             cost train 0.51
#             valid set accuracy 63.42%
#             cost valid 0.52
#
# Epoch 3/40:
#             train set accuracy 68.86%
#             cost train 0.44
#             valid set accuracy 68.72%
#             cost valid 0.44
#
# Epoch 4/40:
#             train set accuracy 72.31%
#             cost train 0.4
#             valid set accuracy 72.16%
#             cost valid 0.4
#
# Epoch 5/40:
#             train set accuracy 78.65%
#             cost train 0.34
#             valid set accuracy 78.58%
#             cost valid 0.34
#
# Epoch 6/40:
#             train set accuracy 81.87%
#             cost train 0.3
#             valid set accuracy 81.93%
#             cost valid 0.3
#
# Epoch 7/40:
#             train set accuracy 83.46%
#             cost train 0.28
#             valid set accuracy 83.07%
#             cost valid 0.28
#
# Epoch 8/40:
#             train set accuracy 85.41%
#             cost train 0.25
#             valid set accuracy 84.86%
#             cost valid 0.25
#
# Epoch 9/40:
#             train set accuracy 85.32%
#             cost train 0.25
#             valid set accuracy 85.28%
#             cost valid 0.25
#
# Epoch 10/40:
#             train set accuracy 86.07%
#             cost train 0.23
#             valid set accuracy 86.01%
#             cost valid 0.24
#
# Epoch 11/40:
#             train set accuracy 87.15%
#             cost train 0.22
#             valid set accuracy 86.58%
#             cost valid 0.23
#
# Epoch 12/40:
#             train set accuracy 87.3%
#             cost train 0.22
#             valid set accuracy 87.02%
#             cost valid 0.22
#
# Epoch 13/40:
#             train set accuracy 87.53%
#             cost train 0.21
#             valid set accuracy 87.29%
#             cost valid 0.22
#
# Epoch 14/40:
#             train set accuracy 87.94%
#             cost train 0.2
#             valid set accuracy 87.52%
#             cost valid 0.21
#
# Epoch 15/40:
#             train set accuracy 88.75%
#             cost train 0.19
#             valid set accuracy 87.95%
#             cost valid 0.2
#
# Epoch 16/40:
#             train set accuracy 89.03%
#             cost train 0.19
#             valid set accuracy 88.62%
#             cost valid 0.19
#
# Epoch 17/40:
#             train set accuracy 89.44%
#             cost train 0.18
#             valid set accuracy 88.98%
#             cost valid 0.18
#
# Epoch 18/40:
#             train set accuracy 89.59%
#             cost train 0.18
#             valid set accuracy 89.34%
#             cost valid 0.18
#
# Epoch 19/40:
#             train set accuracy 89.83%
#             cost train 0.17
#             valid set accuracy 89.42%
#             cost valid 0.18
#
# Epoch 20/40:
#             train set accuracy 89.92%
#             cost train 0.17
#             valid set accuracy 89.49%
#             cost valid 0.18
#
# Epoch 21/40:
#             train set accuracy 90.17%
#             cost train 0.17
#             valid set accuracy 89.53%
#             cost valid 0.18
#
# Epoch 22/40:
#             train set accuracy 90.09%
#             cost train 0.17
#             valid set accuracy 89.61%
#             cost valid 0.18
#
# Epoch 23/40:
#             train set accuracy 90.51%
#             cost train 0.17
#             valid set accuracy 90.1%
#             cost valid 0.17
#
# Epoch 24/40:
#             train set accuracy 90.59%
#             cost train 0.16
#             valid set accuracy 90.24%
#             cost valid 0.17
#
# Epoch 25/40:
#             train set accuracy 90.93%
#             cost train 0.16
#             valid set accuracy 90.24%
#             cost valid 0.16
#
# Epoch 26/40:
#             train set accuracy 91.16%
#             cost train 0.15
#             valid set accuracy 90.59%
#             cost valid 0.16
#
# Epoch 27/40:
#             train set accuracy 91.23%
#             cost train 0.15
#             valid set accuracy 90.65%
#             cost valid 0.16
#
# Epoch 28/40:
#             train set accuracy 91.07%
#             cost train 0.15
#             valid set accuracy 90.17%
#             cost valid 0.16
#
# Epoch 29/40:
#             train set accuracy 90.97%
#             cost train 0.15
#             valid set accuracy 90.54%
#             cost valid 0.16
#
# Epoch 30/40:
#             train set accuracy 91.16%
#             cost train 0.15
#             valid set accuracy 90.51%
#             cost valid 0.16
#
# Epoch 31/40:
#             train set accuracy 91.33%
#             cost train 0.15
#             valid set accuracy 90.6%
#             cost valid 0.16
#
# Epoch 32/40:
#             train set accuracy 91.23%
#             cost train 0.15
#             valid set accuracy 90.88%
#             cost valid 0.16
#
# Epoch 33/40:
#             train set accuracy 91.4%
#             cost train 0.15
#             valid set accuracy 91.12%
#             cost valid 0.15
#
# Epoch 34/40:
#             train set accuracy 91.54%
#             cost train 0.14
#             valid set accuracy 91.15%
#             cost valid 0.15
#
# Epoch 35/40:
#             train set accuracy 91.7%
#             cost train 0.14
#             valid set accuracy 90.86%
#             cost valid 0.15
#
# Epoch 36/40:
#             train set accuracy 91.72%
#             cost train 0.14
#             valid set accuracy 91.05%
#             cost valid 0.15
#
# Epoch 37/40:
#             train set accuracy 91.88%
#             cost train 0.14
#             valid set accuracy 91.41%
#             cost valid 0.15
#
# Epoch 38/40:
#             train set accuracy 92.2%
#             cost train 0.14
#             valid set accuracy 91.57%
#             cost valid 0.15
#
# Epoch 39/40:
#             train set accuracy 92.05%
#             cost train 0.14
#             valid set accuracy 91.53%
#             cost valid 0.15
#
# Epoch 40/40:
#             train set accuracy 92.26%
#             cost train 0.13
#             valid set accuracy 91.37%
#             cost valid 0.15

# %%
network = NeuralNetwork([784, 100, 20, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=80)
# Out:
# Epoch 1/80:
#             train set accuracy 44.68%
#             cost train 0.73
#             valid set accuracy 43.99%
#             cost valid 0.73
#
# Epoch 2/80:
#             train set accuracy 60.77%
#             cost train 0.58
#             valid set accuracy 61.58%
#             cost valid 0.57
#
# Epoch 3/80:
#             train set accuracy 68.7%
#             cost train 0.48
#             valid set accuracy 69.1%
#             cost valid 0.48
#
# Epoch 4/80:
#             train set accuracy 73.95%
#             cost train 0.42
#             valid set accuracy 74.52%
#             cost valid 0.42
#
# Epoch 5/80:
#             train set accuracy 77.57%
#             cost train 0.37
#             valid set accuracy 77.79%
#             cost valid 0.37
#
# Epoch 6/80:
#             train set accuracy 80.11%
#             cost train 0.33
#             valid set accuracy 80.34%
#             cost valid 0.33
#
# Epoch 7/80:
#             train set accuracy 81.38%
#             cost train 0.31
#             valid set accuracy 81.71%
#             cost valid 0.31
#
# Epoch 8/80:
#             train set accuracy 82.6%
#             cost train 0.29
#             valid set accuracy 82.88%
#             cost valid 0.29
#
# Epoch 9/80:
#             train set accuracy 83.82%
#             cost train 0.27
#             valid set accuracy 83.58%
#             cost valid 0.27
#
# Epoch 10/80:
#             train set accuracy 84.11%
#             cost train 0.27
#             valid set accuracy 83.95%
#             cost valid 0.27
#
# Epoch 11/80:
#             train set accuracy 84.82%
#             cost train 0.26
#             valid set accuracy 84.59%
#             cost valid 0.25
#
# Epoch 12/80:
#             train set accuracy 85.49%
#             cost train 0.24
#             valid set accuracy 85.22%
#             cost valid 0.24
#
# Epoch 13/80:
#             train set accuracy 86.2%
#             cost train 0.23
#             valid set accuracy 86.2%
#             cost valid 0.23
#
# Epoch 14/80:
#             train set accuracy 86.1%
#             cost train 0.23
#             valid set accuracy 85.94%
#             cost valid 0.23
#
# Epoch 15/80:
#             train set accuracy 86.56%
#             cost train 0.22
#             valid set accuracy 86.41%
#             cost valid 0.23
#
# Epoch 16/80:
#             train set accuracy 87.1%
#             cost train 0.21
#             valid set accuracy 87.21%
#             cost valid 0.21
#
# Epoch 17/80:
#             train set accuracy 87.27%
#             cost train 0.21
#             valid set accuracy 87.11%
#             cost valid 0.21
#
# Epoch 18/80:
#             train set accuracy 87.4%
#             cost train 0.2
#             valid set accuracy 87.37%
#             cost valid 0.21
#
# Epoch 19/80:
#             train set accuracy 87.39%
#             cost train 0.21
#             valid set accuracy 87.24%
#             cost valid 0.21
#
# Epoch 20/80:
#             train set accuracy 87.68%
#             cost train 0.2
#             valid set accuracy 87.53%
#             cost valid 0.2
#
# Epoch 21/80:
#             train set accuracy 88.22%
#             cost train 0.19
#             valid set accuracy 87.64%
#             cost valid 0.2
#
# Epoch 22/80:
#             train set accuracy 88.62%
#             cost train 0.18
#             valid set accuracy 88.47%
#             cost valid 0.19
#
# Epoch 23/80:
#             train set accuracy 89.08%
#             cost train 0.18
#             valid set accuracy 89.0%
#             cost valid 0.18
#
# Epoch 24/80:
#             train set accuracy 88.81%
#             cost train 0.18
#             valid set accuracy 88.59%
#             cost valid 0.18
#
# Epoch 25/80:
#             train set accuracy 88.8%
#             cost train 0.18
#             valid set accuracy 88.19%
#             cost valid 0.19
#
# Epoch 26/80:
#             train set accuracy 88.6%
#             cost train 0.18
#             valid set accuracy 88.54%
#             cost valid 0.18
#
# Epoch 27/80:
#             train set accuracy 88.8%
#             cost train 0.18
#             valid set accuracy 88.65%
#             cost valid 0.18
#
# Epoch 28/80:
#             train set accuracy 89.2%
#             cost train 0.17
#             valid set accuracy 89.22%
#             cost valid 0.18
#
# Epoch 29/80:
#             train set accuracy 89.05%
#             cost train 0.18
#             valid set accuracy 88.88%
#             cost valid 0.18
#
# Epoch 30/80:
#             train set accuracy 89.34%
#             cost train 0.17
#             valid set accuracy 89.19%
#             cost valid 0.18
#
# Epoch 31/80:
#             train set accuracy 89.46%
#             cost train 0.17
#             valid set accuracy 89.34%
#             cost valid 0.17
#
# Epoch 32/80:
#             train set accuracy 89.64%
#             cost train 0.17
#             valid set accuracy 89.6%
#             cost valid 0.17
#
# Epoch 33/80:
#             train set accuracy 89.81%
#             cost train 0.16
#             valid set accuracy 89.5%
#             cost valid 0.17
#
# Epoch 34/80:
#             train set accuracy 89.78%
#             cost train 0.16
#             valid set accuracy 89.45%
#             cost valid 0.17
#
# Epoch 35/80:
#             train set accuracy 90.07%
#             cost train 0.16
#             valid set accuracy 89.83%
#             cost valid 0.16
#
# Epoch 36/80:
#             train set accuracy 90.42%
#             cost train 0.16
#             valid set accuracy 90.01%
#             cost valid 0.16
#
# Epoch 37/80:
#             train set accuracy 90.31%
#             cost train 0.16
#             valid set accuracy 89.88%
#             cost valid 0.16
#
# Epoch 38/80:
#             train set accuracy 90.21%
#             cost train 0.16
#             valid set accuracy 89.82%
#             cost valid 0.16
#
# Epoch 39/80:
#             train set accuracy 90.07%
#             cost train 0.16
#             valid set accuracy 89.63%
#             cost valid 0.17
#
# Epoch 40/80:
#             train set accuracy 90.04%
#             cost train 0.16
#             valid set accuracy 89.48%
#             cost valid 0.16
#
# Epoch 41/80:
#             train set accuracy 89.89%
#             cost train 0.16
#             valid set accuracy 89.43%
#             cost valid 0.17
#
# Epoch 42/80:
#             train set accuracy 90.01%
#             cost train 0.16
#             valid set accuracy 89.54%
#             cost valid 0.17
#
# Epoch 43/80:
#             train set accuracy 90.36%
#             cost train 0.15
#             valid set accuracy 90.0%
#             cost valid 0.16
#
# Epoch 44/80:
#             train set accuracy 90.76%
#             cost train 0.15
#             valid set accuracy 90.53%
#             cost valid 0.15
#
# Epoch 45/80:
#             train set accuracy 90.87%
#             cost train 0.15
#             valid set accuracy 90.62%
#             cost valid 0.15
#
# Epoch 46/80:
#             train set accuracy 90.87%
#             cost train 0.15
#             valid set accuracy 90.42%
#             cost valid 0.16
#
# Epoch 47/80:
#             train set accuracy 90.71%
#             cost train 0.15
#             valid set accuracy 90.23%
#             cost valid 0.15
#
# Epoch 48/80:
#             train set accuracy 90.62%
#             cost train 0.15
#             valid set accuracy 90.48%
#             cost valid 0.15
#
# Epoch 49/80:
#             train set accuracy 90.9%
#             cost train 0.15
#             valid set accuracy 90.33%
#             cost valid 0.15
#
# Epoch 50/80:
#             train set accuracy 91.15%
#             cost train 0.14
#             valid set accuracy 91.06%
#             cost valid 0.15
#
# Epoch 51/80:
#             train set accuracy 91.3%
#             cost train 0.14
#             valid set accuracy 90.72%
#             cost valid 0.15
#
# Epoch 52/80:
#             train set accuracy 91.02%
#             cost train 0.14
#             valid set accuracy 90.67%
#             cost valid 0.15
#
# Epoch 53/80:
#             train set accuracy 90.86%
#             cost train 0.14
#             valid set accuracy 90.33%
#             cost valid 0.15
#
# Epoch 54/80:
#             train set accuracy 91.24%
#             cost train 0.14
#             valid set accuracy 90.8%
#             cost valid 0.14
#
# Epoch 55/80:
#             train set accuracy 91.13%
#             cost train 0.14
#             valid set accuracy 91.02%
#             cost valid 0.14
#
# Epoch 56/80:
#             train set accuracy 91.32%
#             cost train 0.14
#             valid set accuracy 90.96%
#             cost valid 0.14
#
# Epoch 57/80:
#             train set accuracy 91.34%
#             cost train 0.14
#             valid set accuracy 91.18%
#             cost valid 0.14
# Epoch 58/80:
#             train set accuracy 91.43%
#             cost train 0.14
#             valid set accuracy 90.94%
#             cost valid 0.15
#
# Epoch 59/80:
#             train set accuracy 91.41%
#             cost train 0.14
#             valid set accuracy 90.72%
#             cost valid 0.14
#
# Epoch 60/80:
#             train set accuracy 91.34%
#             cost train 0.14
#             valid set accuracy 90.92%
#             cost valid 0.15
#
# Epoch 61/80:
#             train set accuracy 91.43%
#             cost train 0.14
#             valid set accuracy 91.07%
#             cost valid 0.14
#
# Epoch 62/80:
#             train set accuracy 91.54%
#             cost train 0.14
#             valid set accuracy 91.21%
#             cost valid 0.14
#
# Epoch 63/80:
#             train set accuracy 91.48%
#             cost train 0.14
#             valid set accuracy 90.88%
#             cost valid 0.15
#
# Epoch 64/80:
#             train set accuracy 91.81%
#             cost train 0.13
#             valid set accuracy 91.27%
#             cost valid 0.14
#
# Epoch 65/80:
#             train set accuracy 91.75%
#             cost train 0.13
#             valid set accuracy 91.07%
#             cost valid 0.14
#
# Epoch 66/80:
#             train set accuracy 91.96%
#             cost train 0.13
#             valid set accuracy 91.38%
#             cost valid 0.14
#
# Epoch 67/80:
#             train set accuracy 91.69%
#             cost train 0.13
#             valid set accuracy 91.53%
#             cost valid 0.14
#
# Epoch 68/80:
#             train set accuracy 92.05%
#             cost train 0.13
#             valid set accuracy 91.62%
#             cost valid 0.14
#
# Epoch 69/80:
#             train set accuracy 91.62%
#             cost train 0.13
#             valid set accuracy 91.47%
#             cost valid 0.14
#
# Epoch 70/80:
#             train set accuracy 91.89%
#             cost train 0.13
#             valid set accuracy 91.53%
#             cost valid 0.14
#
# Epoch 71/80:
#             train set accuracy 91.95%
#             cost train 0.13
#             valid set accuracy 91.35%
#             cost valid 0.14
#
# Epoch 72/80:
#             train set accuracy 91.85%
#             cost train 0.13
#             valid set accuracy 91.85%
#             cost valid 0.13
#
# Epoch 73/80:
#             train set accuracy 91.94%
#             cost train 0.13
#             valid set accuracy 91.57%
#             cost valid 0.13
#
# Epoch 74/80:
#             train set accuracy 91.4%
#             cost train 0.14
#             valid set accuracy 91.18%
#             cost valid 0.14
#
# Epoch 75/80:
#             train set accuracy 91.29%
#             cost train 0.14
#             valid set accuracy 91.08%
#             cost valid 0.14
#
# Epoch 76/80:
#             train set accuracy 91.42%
#             cost train 0.14
#             valid set accuracy 90.93%
#             cost valid 0.14
#
# Epoch 77/80:
#             train set accuracy 91.84%
#             cost train 0.13
#             valid set accuracy 91.12%
#             cost valid 0.14
#
# Epoch 78/80:
#             train set accuracy 91.5%
#             cost train 0.14
#             valid set accuracy 90.79%
#             cost valid 0.15
#
# Epoch 79/80:
#             train set accuracy 91.67%
#             cost train 0.13
#             valid set accuracy 91.23%
#             cost valid 0.14
#
# Epoch 80/80:
#             train set accuracy 92.13%
#             cost train 0.13
#             valid set accuracy 91.79%
#             cost valid 0.13

# %%
network = NeuralNetwork([784, 100, 20, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=120)
# Out:
# Epoch 1/120:
#             train set accuracy 35.37%
#             cost train 0.8
#             valid set accuracy 35.01%
#             cost valid 0.8
#
# Epoch 2/120:
#             train set accuracy 52.51%
#             cost train 0.65
#             valid set accuracy 52.87%
#             cost valid 0.65
#
# Epoch 3/120:
#             train set accuracy 62.89%
#             cost train 0.55
#             valid set accuracy 62.7%
#             cost valid 0.55
#
# Epoch 4/120:
#             train set accuracy 69.54%
#             cost train 0.47
#             valid set accuracy 69.62%
#             cost valid 0.47
#
# Epoch 5/120:
#             train set accuracy 74.51%
#             cost train 0.42
#             valid set accuracy 74.34%
#             cost valid 0.42
#
# Epoch 6/120:
#             train set accuracy 76.74%
#             cost train 0.38
#             valid set accuracy 77.0%
#             cost valid 0.38
#
# Epoch 7/120:
#             train set accuracy 78.71%
#             cost train 0.35
#             valid set accuracy 78.88%
#             cost valid 0.35
#
# Epoch 8/120:
#             train set accuracy 80.8%
#             cost train 0.32
#             valid set accuracy 80.62%
#             cost valid 0.32
#
# Epoch 9/120:
#             train set accuracy 82.08%
#             cost train 0.3
#             valid set accuracy 82.03%
#             cost valid 0.3
#
# Epoch 10/120:
#             train set accuracy 83.05%
#             cost train 0.28
#             valid set accuracy 82.46%
#             cost valid 0.29
#
# Epoch 11/120:
#             train set accuracy 83.81%
#             cost train 0.27
#             valid set accuracy 83.67%
#             cost valid 0.27
#
# Epoch 12/120:
#             train set accuracy 84.2%
#             cost train 0.26
#             valid set accuracy 84.51%
#             cost valid 0.26
#
# Epoch 13/120:
#             train set accuracy 84.56%
#             cost train 0.25
#             valid set accuracy 84.67%
#             cost valid 0.25
#
# Epoch 14/120:
#             train set accuracy 85.32%
#             cost train 0.24
#             valid set accuracy 85.06%
#             cost valid 0.24
#
# Epoch 15/120:
#             train set accuracy 85.51%
#             cost train 0.24
#             valid set accuracy 85.55%
#             cost valid 0.24
#
# Epoch 16/120:
#             train set accuracy 86.18%
#             cost train 0.23
#             valid set accuracy 85.77%
#             cost valid 0.23
#
# Epoch 17/120:
#             train set accuracy 85.95%
#             cost train 0.23
#             valid set accuracy 85.73%
#             cost valid 0.23
#
# Epoch 18/120:
#             train set accuracy 86.1%
#             cost train 0.22
#             valid set accuracy 86.38%
#             cost valid 0.22
#
# Epoch 19/120:
#             train set accuracy 86.83%
#             cost train 0.22
#             valid set accuracy 86.59%
#             cost valid 0.22
#
# Epoch 20/120:
#             train set accuracy 87.05%
#             cost train 0.21
#             valid set accuracy 86.81%
#             cost valid 0.21
#
# Epoch 21/120:
#             train set accuracy 86.78%
#             cost train 0.21
#             valid set accuracy 86.58%
#             cost valid 0.22
#
# Epoch 22/120:
#             train set accuracy 87.53%
#             cost train 0.2
#             valid set accuracy 87.18%
#             cost valid 0.2
#
# Epoch 23/120:
#             train set accuracy 87.59%
#             cost train 0.2
#             valid set accuracy 87.39%
#             cost valid 0.2
#
# Epoch 24/120:
#             train set accuracy 87.95%
#             cost train 0.2
#             valid set accuracy 87.76%
#             cost valid 0.2
#
# Epoch 25/120:
#             train set accuracy 88.13%
#             cost train 0.19
#             valid set accuracy 87.79%
#             cost valid 0.19
#
# Epoch 26/120:
#             train set accuracy 88.17%
#             cost train 0.19
#             valid set accuracy 87.9%
#             cost valid 0.19
#
# Epoch 27/120:
#             train set accuracy 88.5%
#             cost train 0.19
#             valid set accuracy 88.33%
#             cost valid 0.19
#
# Epoch 28/120:
#             train set accuracy 88.71%
#             cost train 0.18
#             valid set accuracy 88.47%
#             cost valid 0.19
#
# Epoch 29/120:
#             train set accuracy 88.88%
#             cost train 0.18
#             valid set accuracy 88.52%
#             cost valid 0.19
#
# Epoch 30/120:
#             train set accuracy 88.72%
#             cost train 0.18
#             valid set accuracy 88.67%
#             cost valid 0.19
#
# Epoch 31/120:
#             train set accuracy 88.87%
#             cost train 0.18
#             valid set accuracy 88.62%
#             cost valid 0.18
#
# Epoch 32/120:
#             train set accuracy 89.25%
#             cost train 0.18
#             valid set accuracy 88.83%
#             cost valid 0.18
#
# Epoch 33/120:
#             train set accuracy 89.45%
#             cost train 0.17
#             valid set accuracy 89.2%
#             cost valid 0.17
#
# Epoch 34/120:
#             train set accuracy 89.22%
#             cost train 0.17
#             valid set accuracy 89.18%
#             cost valid 0.17
#
# Epoch 35/120:
#             train set accuracy 89.42%
#             cost train 0.17
#             valid set accuracy 89.15%
#             cost valid 0.17
#
# Epoch 36/120:
#             train set accuracy 89.42%
#             cost train 0.17
#             valid set accuracy 89.14%
#             cost valid 0.17
#
# Epoch 37/120:
#             train set accuracy 89.39%
#             cost train 0.17
#             valid set accuracy 89.07%
#             cost valid 0.17
#
# Epoch 38/120:
#             train set accuracy 89.52%
#             cost train 0.17
#             valid set accuracy 89.19%
#             cost valid 0.17
#
# Epoch 39/120:
#             train set accuracy 89.72%
#             cost train 0.17
#             valid set accuracy 89.53%
#             cost valid 0.17
#
# Epoch 40/120:
#             train set accuracy 89.61%
#             cost train 0.17
#             valid set accuracy 89.12%
#             cost valid 0.18
#
# Epoch 41/120:
#             train set accuracy 89.83%
#             cost train 0.16
#             valid set accuracy 89.34%
#             cost valid 0.17
#
# Epoch 42/120:
#             train set accuracy 90.12%
#             cost train 0.16
#             valid set accuracy 89.76%
#             cost valid 0.16
#
# Epoch 43/120:
#             train set accuracy 90.14%
#             cost train 0.16
#             valid set accuracy 89.84%
#             cost valid 0.16
#
# Epoch 44/120:
#             train set accuracy 90.41%
#             cost train 0.15
#             valid set accuracy 89.88%
#             cost valid 0.16
#
# Epoch 45/120:
#             train set accuracy 90.33%
#             cost train 0.16
#             valid set accuracy 89.95%
#             cost valid 0.16
#
# Epoch 46/120:
#             train set accuracy 90.54%
#             cost train 0.15
#             valid set accuracy 90.03%
#             cost valid 0.16
#
# Epoch 47/120:
#             train set accuracy 90.58%
#             cost train 0.15
#             valid set accuracy 89.96%
#             cost valid 0.16
#
# Epoch 48/120:
#             train set accuracy 90.35%
#             cost train 0.15
#             valid set accuracy 90.01%
#             cost valid 0.16
#
# Epoch 49/120:
#             train set accuracy 90.24%
#             cost train 0.16
#             valid set accuracy 90.22%
#             cost valid 0.16
#
# Epoch 50/120:
#             train set accuracy 90.4%
#             cost train 0.15
#             valid set accuracy 90.03%
#             cost valid 0.16
#
# Epoch 51/120:
#             train set accuracy 90.56%
#             cost train 0.15
#             valid set accuracy 89.92%
#             cost valid 0.16
#
# Epoch 52/120:
#             train set accuracy 90.42%
#             cost train 0.15
#             valid set accuracy 89.83%
#             cost valid 0.16
#
# Epoch 53/120:
#             train set accuracy 90.52%
#             cost train 0.15
#             valid set accuracy 89.98%
#             cost valid 0.16
#
# Epoch 54/120:
#             train set accuracy 90.43%
#             cost train 0.15
#             valid set accuracy 89.99%
#             cost valid 0.16
#
# Epoch 55/120:
#             train set accuracy 90.74%
#             cost train 0.15
#             valid set accuracy 90.24%
#             cost valid 0.15
#
# Epoch 56/120:
#             train set accuracy 90.91%
#             cost train 0.14
#             valid set accuracy 90.53%
#             cost valid 0.15
# Epoch 57/120:
#             train set accuracy 90.68%
#             cost train 0.15
#             valid set accuracy 90.08%
#             cost valid 0.16
#
# Epoch 58/120:
#             train set accuracy 91.05%
#             cost train 0.14
#             valid set accuracy 90.4%
#             cost valid 0.15
#
# Epoch 59/120:
#             train set accuracy 91.08%
#             cost train 0.14
#             valid set accuracy 90.43%
#             cost valid 0.15
#
# Epoch 60/120:
#             train set accuracy 91.48%
#             cost train 0.14
#             valid set accuracy 91.27%
#             cost valid 0.14
#
# Epoch 61/120:
#             train set accuracy 91.14%
#             cost train 0.14
#             valid set accuracy 90.83%
#             cost valid 0.15
#
# Epoch 62/120:
#             train set accuracy 91.43%
#             cost train 0.14
#             valid set accuracy 91.08%
#             cost valid 0.14
#
# Epoch 63/120:
#             train set accuracy 91.55%
#             cost train 0.13
#             valid set accuracy 91.22%
#             cost valid 0.14
#
# Epoch 64/120:
#             train set accuracy 91.49%
#             cost train 0.14
#             valid set accuracy 91.19%
#             cost valid 0.14
#
# Epoch 65/120:
#             train set accuracy 91.8%
#             cost train 0.13
#             valid set accuracy 91.37%
#             cost valid 0.14
#
# Epoch 66/120:
#             train set accuracy 91.55%
#             cost train 0.14
#             valid set accuracy 91.33%
#             cost valid 0.14
#
# Epoch 67/120:
#             train set accuracy 91.62%
#             cost train 0.14
#             valid set accuracy 90.9%
#             cost valid 0.14
#
# Epoch 68/120:
#             train set accuracy 91.66%
#             cost train 0.13
#             valid set accuracy 91.5%
#             cost valid 0.14
#
# Epoch 69/120:
#             train set accuracy 91.49%
#             cost train 0.14
#             valid set accuracy 91.19%
#             cost valid 0.14
#
# Epoch 70/120:
#             train set accuracy 91.52%
#             cost train 0.14
#             valid set accuracy 91.17%
#             cost valid 0.14
#
# Epoch 71/120:
#             train set accuracy 91.54%
#             cost train 0.13
#             valid set accuracy 90.96%
#             cost valid 0.14
#
# Epoch 72/120:
#             train set accuracy 91.88%
#             cost train 0.13
#             valid set accuracy 91.57%
#             cost valid 0.14
#
# Epoch 73/120:
#             train set accuracy 91.84%
#             cost train 0.13
#             valid set accuracy 91.27%
#             cost valid 0.14
#
# Epoch 74/120:
#             train set accuracy 91.84%
#             cost train 0.13
#             valid set accuracy 91.33%
#             cost valid 0.14
#
# Epoch 75/120:
#             train set accuracy 92.05%
#             cost train 0.13
#             valid set accuracy 91.57%
#             cost valid 0.13
#
# Epoch 76/120:
#             train set accuracy 92.12%
#             cost train 0.13
#             valid set accuracy 91.64%
#             cost valid 0.13
#
# Epoch 77/120:
#             train set accuracy 91.88%
#             cost train 0.13
#             valid set accuracy 91.46%
#             cost valid 0.14
#
# Epoch 78/120:
#             train set accuracy 91.84%
#             cost train 0.13
#             valid set accuracy 91.22%
#             cost valid 0.14
#
# Epoch 79/120:
#             train set accuracy 91.69%
#             cost train 0.13
#             valid set accuracy 91.4%
#             cost valid 0.14
#
# Epoch 80/120:
#             train set accuracy 91.92%
#             cost train 0.13
#             valid set accuracy 91.07%
#             cost valid 0.14
#
# Epoch 81/120:
#             train set accuracy 92.16%
#             cost train 0.13
#             valid set accuracy 91.81%
#             cost valid 0.13
#
# Epoch 82/120:
#             train set accuracy 92.11%
#             cost train 0.12
#             valid set accuracy 91.63%
#             cost valid 0.13
#
# Epoch 83/120:
#             train set accuracy 92.29%
#             cost train 0.12
#             valid set accuracy 91.53%
#             cost valid 0.13
#
# Epoch 84/120:
#             train set accuracy 92.02%
#             cost train 0.13
#             valid set accuracy 91.53%
#             cost valid 0.13
#
# Epoch 85/120:
#             train set accuracy 92.09%
#             cost train 0.13
#             valid set accuracy 91.62%
#             cost valid 0.14
#
# Epoch 86/120:
#             train set accuracy 92.27%
#             cost train 0.12
#             valid set accuracy 91.77%
#             cost valid 0.13
#
# Epoch 87/120:
#             train set accuracy 92.1%
#             cost train 0.13
#             valid set accuracy 91.69%
#             cost valid 0.13
#
# Epoch 88/120:
#             train set accuracy 92.2%
#             cost train 0.13
#             valid set accuracy 91.66%
#             cost valid 0.13
#
# Epoch 89/120:
#             train set accuracy 91.89%
#             cost train 0.13
#             valid set accuracy 91.27%
#             cost valid 0.14
#
# Epoch 90/120:
#             train set accuracy 92.22%
#             cost train 0.13
#             valid set accuracy 91.77%
#             cost valid 0.13
#
# Epoch 91/120:
#             train set accuracy 92.28%
#             cost train 0.12
#             valid set accuracy 91.73%
#             cost valid 0.13
#
# Epoch 92/120:
#             train set accuracy 92.31%
#             cost train 0.12
#             valid set accuracy 91.83%
#             cost valid 0.13
#
# Epoch 93/120:
#             train set accuracy 92.3%
#             cost train 0.12
#             valid set accuracy 91.71%
#             cost valid 0.13
#
# Epoch 94/120:
#             train set accuracy 92.19%
#             cost train 0.13
#             valid set accuracy 91.67%
#             cost valid 0.13
#
# Epoch 95/120:
#             train set accuracy 92.25%
#             cost train 0.12
#             valid set accuracy 91.83%
#             cost valid 0.13
#
# Epoch 96/120:
#             train set accuracy 91.66%
#             cost train 0.13
#             valid set accuracy 91.54%
#             cost valid 0.13
#
# Epoch 97/120:
#             train set accuracy 92.5%
#             cost train 0.12
#             valid set accuracy 91.89%
#             cost valid 0.13
#
# Epoch 98/120:
#             train set accuracy 92.6%
#             cost train 0.12
#             valid set accuracy 92.03%
#             cost valid 0.13
#
# Epoch 99/120:
#             train set accuracy 92.67%
#             cost train 0.12
#             valid set accuracy 92.04%
#             cost valid 0.13
#
# Epoch 100/120:
#             train set accuracy 92.56%
#             cost train 0.12
#             valid set accuracy 92.08%
#             cost valid 0.13
#
# Epoch 101/120:
#             train set accuracy 92.81%
#             cost train 0.12
#             valid set accuracy 92.26%
#             cost valid 0.12
#
# Epoch 102/120:
#             train set accuracy 92.84%
#             cost train 0.11
#             valid set accuracy 92.19%
#             cost valid 0.12
#
# Epoch 103/120:
#             train set accuracy 92.56%
#             cost train 0.12
#             valid set accuracy 91.88%
#             cost valid 0.13
#
# Epoch 104/120:
#             train set accuracy 92.3%
#             cost train 0.12
#             valid set accuracy 91.61%
#             cost valid 0.13
#
# Epoch 105/120:
#             train set accuracy 92.18%
#             cost train 0.12
#             valid set accuracy 91.59%
#             cost valid 0.13
#
# Epoch 106/120:
#             train set accuracy 92.83%
#             cost train 0.12
#             valid set accuracy 92.03%
#             cost valid 0.13
#
# Epoch 107/120:
#             train set accuracy 92.8%
#             cost train 0.12
#             valid set accuracy 91.93%
#             cost valid 0.12
#
# Epoch 108/120:
#             train set accuracy 92.68%
#             cost train 0.12
#             valid set accuracy 92.15%
#             cost valid 0.12
#
# Epoch 109/120:
#             train set accuracy 92.66%
#             cost train 0.12
#             valid set accuracy 92.14%
#             cost valid 0.13
#
# Epoch 110/120:
#             train set accuracy 92.69%
#             cost train 0.12
#             valid set accuracy 92.04%
#             cost valid 0.13
#
# Epoch 111/120:
#             train set accuracy 93.06%
#             cost train 0.11
#             valid set accuracy 92.29%
#             cost valid 0.12
#
# Epoch 112/120:
#             train set accuracy 93.3%
#             cost train 0.11
#             valid set accuracy 92.42%
#             cost valid 0.12
# Epoch 113/120:
#             train set accuracy 93.1%
#             cost train 0.11
#             valid set accuracy 92.47%
#             cost valid 0.12
#
# Epoch 114/120:
#             train set accuracy 93.15%
#             cost train 0.11
#             valid set accuracy 92.51%
#             cost valid 0.12
#
# Epoch 115/120:
#             train set accuracy 93.11%
#             cost train 0.11
#             valid set accuracy 92.56%
#             cost valid 0.12
#
# Epoch 116/120:
#             train set accuracy 92.72%
#             cost train 0.12
#             valid set accuracy 92.17%
#             cost valid 0.12
#
# Epoch 117/120:
#             train set accuracy 93.07%
#             cost train 0.11
#             valid set accuracy 92.23%
#             cost valid 0.12
#
# Epoch 118/120:
#             train set accuracy 93.17%
#             cost train 0.11
#             valid set accuracy 92.48%
#             cost valid 0.12
#
# Epoch 119/120:
#             train set accuracy 92.73%
#             cost train 0.12
#             valid set accuracy 92.07%
#             cost valid 0.12
#
# Epoch 120/120:
#             train set accuracy 92.97%
#             cost train 0.11
#             valid set accuracy 92.61%
#             cost valid 0.12

# %%
network = NeuralNetwork([784, 100, 20, 10])
network.learn_with_epochs(training_data, learn_rate=0.2, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 67.53%
#             cost train 0.5
#             valid set accuracy 67.9%
#             cost valid 0.5
#
# Epoch 2/40:
#             train set accuracy 75.56%
#             cost train 0.39
#             valid set accuracy 75.55%
#             cost valid 0.39
#
# Epoch 3/40:
#             train set accuracy 79.37%
#             cost train 0.34
#             valid set accuracy 79.15%
#             cost valid 0.34
#
# Epoch 4/40:
#             train set accuracy 81.73%
#             cost train 0.3
#             valid set accuracy 82.01%
#             cost valid 0.3
#
# Epoch 5/40:
#             train set accuracy 81.37%
#             cost train 0.3
#             valid set accuracy 81.4%
#             cost valid 0.3
#
# Epoch 6/40:
#             train set accuracy 81.24%
#             cost train 0.3
#             valid set accuracy 81.77%
#             cost valid 0.29
#
# Epoch 7/40:
#             train set accuracy 81.8%
#             cost train 0.29
#             valid set accuracy 82.13%
#             cost valid 0.29
#
# Epoch 8/40:
#             train set accuracy 80.87%
#             cost train 0.3
#             valid set accuracy 81.65%
#             cost valid 0.29
#
# Epoch 9/40:
#             train set accuracy 81.8%
#             cost train 0.28
#             valid set accuracy 81.62%
#             cost valid 0.28
#
# Epoch 10/40:
#             train set accuracy 81.76%
#             cost train 0.28
#             valid set accuracy 82.04%
#             cost valid 0.28
#
# Epoch 11/40:
#             train set accuracy 83.49%
#             cost train 0.26
#             valid set accuracy 83.71%
#             cost valid 0.25
#
# Epoch 12/40:
#             train set accuracy 83.45%
#             cost train 0.26
#             valid set accuracy 83.33%
#             cost valid 0.26
#
# Epoch 13/40:
#             train set accuracy 83.36%
#             cost train 0.26
#             valid set accuracy 83.38%
#             cost valid 0.26
#
# Epoch 14/40:
#             train set accuracy 84.47%
#             cost train 0.25
#             valid set accuracy 84.38%
#             cost valid 0.25
#
# Epoch 15/40:
#             train set accuracy 84.38%
#             cost train 0.24
#             valid set accuracy 84.35%
#             cost valid 0.24
#
# Epoch 16/40:
#             train set accuracy 83.08%
#             cost train 0.26
#             valid set accuracy 83.56%
#             cost valid 0.26
#
# Epoch 17/40:
#             train set accuracy 81.14%
#             cost train 0.28
#             valid set accuracy 81.62%
#             cost valid 0.28
#
# Epoch 18/40:
#             train set accuracy 82.8%
#             cost train 0.26
#             valid set accuracy 83.66%
#             cost valid 0.25
#
# Epoch 19/40:
#             train set accuracy 81.82%
#             cost train 0.28
#             valid set accuracy 82.32%
#             cost valid 0.27
#
# Epoch 20/40:
#             train set accuracy 82.69%
#             cost train 0.26
#             valid set accuracy 82.79%
#             cost valid 0.26
#
# Epoch 21/40:
#             train set accuracy 84.09%
#             cost train 0.25
#             valid set accuracy 84.44%
#             cost valid 0.24
#
# Epoch 22/40:
#             train set accuracy 84.08%
#             cost train 0.25
#             valid set accuracy 84.34%
#             cost valid 0.24
#
# Epoch 23/40:
#             train set accuracy 83.22%
#             cost train 0.25
#             valid set accuracy 83.53%
#             cost valid 0.25
#
# Epoch 24/40:
#             train set accuracy 83.59%
#             cost train 0.25
#             valid set accuracy 84.12%
#             cost valid 0.25
#
# Epoch 25/40:
#             train set accuracy 84.36%
#             cost train 0.24
#             valid set accuracy 84.57%
#             cost valid 0.24
#
# Epoch 26/40:
#             train set accuracy 85.31%
#             cost train 0.23
#             valid set accuracy 85.52%
#             cost valid 0.23
#
# Epoch 27/40:
#             train set accuracy 84.59%
#             cost train 0.24
#             valid set accuracy 84.64%
#             cost valid 0.24
#
# Epoch 28/40:
#             train set accuracy 84.64%
#             cost train 0.24
#             valid set accuracy 84.97%
#             cost valid 0.24
#
# Epoch 29/40:
#             train set accuracy 85.59%
#             cost train 0.22
#             valid set accuracy 85.72%
#             cost valid 0.22
#
# Epoch 30/40:
#             train set accuracy 85.88%
#             cost train 0.22
#             valid set accuracy 85.99%
#             cost valid 0.21
#
# Epoch 31/40:
#             train set accuracy 83.76%
#             cost train 0.25
#             valid set accuracy 83.89%
#             cost valid 0.24
#
# Epoch 32/40:
#             train set accuracy 83.67%
#             cost train 0.25
#             valid set accuracy 83.93%
#             cost valid 0.24
#
# Epoch 33/40:
#             train set accuracy 84.19%
#             cost train 0.24
#             valid set accuracy 84.15%
#             cost valid 0.24
#
# Epoch 34/40:
#             train set accuracy 84.0%
#             cost train 0.24
#             valid set accuracy 84.15%
#             cost valid 0.24
#
# Epoch 35/40:
#             train set accuracy 83.55%
#             cost train 0.25
#             valid set accuracy 82.88%
#             cost valid 0.26
#
# Epoch 36/40:
#             train set accuracy 84.86%
#             cost train 0.23
#             valid set accuracy 84.5%
#             cost valid 0.23
#
# Epoch 37/40:
#             train set accuracy 84.09%
#             cost train 0.24
#             valid set accuracy 84.38%
#             cost valid 0.24
#
# Epoch 38/40:
#             train set accuracy 83.44%
#             cost train 0.25
#             valid set accuracy 83.38%
#             cost valid 0.25
#
# Epoch 39/40:
#             train set accuracy 85.25%
#             cost train 0.23
#             valid set accuracy 85.44%
#             cost valid 0.23
#
# Epoch 40/40:
#             train set accuracy 84.66%
#             cost train 0.24
#             valid set accuracy 84.47%
#             cost valid 0.24

# %%
network = NeuralNetwork([784, 100, 20, 10])
network.learn_with_epochs(training_data, learn_rate=0.5, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 60.91%
#             cost train 0.53
#             valid set accuracy 61.85%
#             cost valid 0.52
#
# Epoch 2/40:
#             train set accuracy 61.76%
#             cost train 0.53
#             valid set accuracy 62.48%
#             cost valid 0.53
#
# Epoch 3/40:
#             train set accuracy 67.18%
#             cost train 0.47
#             valid set accuracy 67.77%
#             cost valid 0.46
#
# Epoch 4/40:
#             train set accuracy 66.99%
#             cost train 0.46
#             valid set accuracy 67.19%
#             cost valid 0.46
#
# Epoch 5/40:
#             train set accuracy 65.72%
#             cost train 0.48
#             valid set accuracy 66.17%
#             cost valid 0.47
#
# Epoch 6/40:
#             train set accuracy 68.01%
#             cost train 0.44
#             valid set accuracy 68.4%
#             cost valid 0.43
#
# Epoch 7/40:
#             train set accuracy 68.37%
#             cost train 0.44
#             valid set accuracy 68.97%
#             cost valid 0.43
#
# Epoch 8/40:
#             train set accuracy 69.04%
#             cost train 0.44
#             valid set accuracy 69.42%
#             cost valid 0.43
#
# Epoch 9/40:
#             train set accuracy 69.62%
#             cost train 0.43
#             valid set accuracy 69.77%
#             cost valid 0.42
#
# Epoch 10/40:
#             train set accuracy 72.08%
#             cost train 0.42
#             valid set accuracy 72.05%
#             cost valid 0.42
#
# Epoch 11/40:
#             train set accuracy 73.26%
#             cost train 0.38
#             valid set accuracy 72.75%
#             cost valid 0.38
#
# Epoch 12/40:
#             train set accuracy 68.03%
#             cost train 0.45
#             valid set accuracy 67.64%
#             cost valid 0.45
#
# Epoch 13/40:
#             train set accuracy 72.22%
#             cost train 0.4
#             valid set accuracy 72.38%
#             cost valid 0.4
#
# Epoch 14/40:
#             train set accuracy 74.51%
#             cost train 0.37
#             valid set accuracy 74.74%
#             cost valid 0.37
#
# Epoch 15/40:
#             train set accuracy 73.63%
#             cost train 0.39
#             valid set accuracy 73.87%
#             cost valid 0.38
#
# Epoch 16/40:
#             train set accuracy 72.79%
#             cost train 0.4
#             valid set accuracy 73.03%
#             cost valid 0.39
#
# Epoch 17/40:
#             train set accuracy 75.27%
#             cost train 0.37
#             valid set accuracy 75.38%
#             cost valid 0.37
#
# Epoch 18/40:
#             train set accuracy 74.54%
#             cost train 0.37
#             valid set accuracy 74.56%
#             cost valid 0.37
#
# Epoch 19/40:
#             train set accuracy 75.11%
#             cost train 0.36
#             valid set accuracy 75.13%
#             cost valid 0.35
#
# Epoch 20/40:
#             train set accuracy 70.63%
#             cost train 0.41
#             valid set accuracy 71.28%
#             cost valid 0.41
#
# Epoch 21/40:
#             train set accuracy 71.41%
#             cost train 0.41
#             valid set accuracy 71.15%
#             cost valid 0.41
#
# Epoch 22/40:
#             train set accuracy 67.5%
#             cost train 0.44
#             valid set accuracy 67.64%
#             cost valid 0.44
#
# Epoch 23/40:
#             train set accuracy 68.37%
#             cost train 0.45
#             valid set accuracy 68.41%
#             cost valid 0.44
#
# Epoch 24/40:
#             train set accuracy 56.14%
#             cost train 0.58
#             valid set accuracy 57.03%
#             cost valid 0.57
#
# Epoch 25/40:
#             train set accuracy 65.28%
#             cost train 0.47
#             valid set accuracy 65.9%
#             cost valid 0.47
#
# Epoch 26/40:
#             train set accuracy 68.02%
#             cost train 0.45
#             valid set accuracy 69.01%
#             cost valid 0.45
#
# Epoch 27/40:
#             train set accuracy 66.02%
#             cost train 0.48
#             valid set accuracy 66.67%
#             cost valid 0.47
#
# Epoch 28/40:
#             train set accuracy 63.0%
#             cost train 0.5
#             valid set accuracy 63.46%
#             cost valid 0.5
#
# Epoch 29/40:
#             train set accuracy 64.39%
#             cost train 0.5
#             valid set accuracy 65.64%
#             cost valid 0.48
#
# Epoch 30/40:
#             train set accuracy 70.53%
#             cost train 0.42
#             valid set accuracy 71.05%
#             cost valid 0.41
#
# Epoch 31/40:
#             train set accuracy 70.07%
#             cost train 0.43
#             valid set accuracy 70.71%
#             cost valid 0.42
#
# Epoch 32/40:
#             train set accuracy 65.95%
#             cost train 0.47
#             valid set accuracy 66.2%
#             cost valid 0.47
#
# Epoch 33/40:
#             train set accuracy 68.03%
#             cost train 0.44
#             valid set accuracy 68.91%
#             cost valid 0.43
#
# Epoch 34/40:
#             train set accuracy 71.95%
#             cost train 0.41
#             valid set accuracy 72.09%
#             cost valid 0.41
#
# Epoch 35/40:
#             train set accuracy 72.04%
#             cost train 0.41
#             valid set accuracy 72.35%
#             cost valid 0.4
#
# Epoch 36/40:
#             train set accuracy 69.31%
#             cost train 0.45
#             valid set accuracy 69.89%
#             cost valid 0.44
#
# Epoch 37/40:
#             train set accuracy 69.5%
#             cost train 0.43
#             valid set accuracy 69.67%
#             cost valid 0.43
#
# Epoch 38/40:
#             train set accuracy 67.92%
#             cost train 0.44
#             valid set accuracy 67.99%
#             cost valid 0.44
#
# Epoch 39/40:
#             train set accuracy 67.49%
#             cost train 0.44
#             valid set accuracy 68.38%
#             cost valid 0.44
#
# Epoch 40/40:
#             train set accuracy 71.62%
#             cost train 0.4
#             valid set accuracy 72.66%
#             cost valid 0.39

# %%
network = NeuralNetwork([784, 100, 20, 10])
network.learn_with_epochs(training_data, learn_rate=0.01, batch_size=30, epochs=40)
# Out:
# Epoch 1/40:
#             train set accuracy 19.62%
#             cost train 0.9
#             valid set accuracy 19.85%
#             cost valid 0.9
#
# Epoch 2/40:
#             train set accuracy 26.83%
#             cost train 0.86
#             valid set accuracy 27.12%
#             cost valid 0.86
#
# Epoch 3/40:
#             train set accuracy 32.85%
#             cost train 0.82
#             valid set accuracy 32.87%
#             cost valid 0.82
#
# Epoch 4/40:
#             train set accuracy 37.49%
#             cost train 0.78
#             valid set accuracy 37.21%
#             cost valid 0.78
#
# Epoch 5/40:
#             train set accuracy 41.55%
#             cost train 0.74
#             valid set accuracy 41.52%
#             cost valid 0.74
#
# Epoch 6/40:
#             train set accuracy 45.28%
#             cost train 0.71
#             valid set accuracy 45.22%
#             cost valid 0.71
#
# Epoch 7/40:
#             train set accuracy 48.69%
#             cost train 0.68
#             valid set accuracy 48.38%
#             cost valid 0.68
#
# Epoch 8/40:
#             train set accuracy 51.42%
#             cost train 0.65
#             valid set accuracy 51.21%
#             cost valid 0.65
#
# Epoch 9/40:
#             train set accuracy 54.19%
#             cost train 0.63
#             valid set accuracy 53.76%
#             cost valid 0.63
#
# Epoch 10/40:
#             train set accuracy 56.41%
#             cost train 0.61
#             valid set accuracy 55.93%
#             cost valid 0.61
#
# Epoch 11/40:
#             train set accuracy 58.6%
#             cost train 0.58
#             valid set accuracy 58.17%
#             cost valid 0.59
#
# Epoch 12/40:
#             train set accuracy 59.91%
#             cost train 0.57
#             valid set accuracy 59.5%
#             cost valid 0.57
#
# Epoch 13/40:
#             train set accuracy 61.51%
#             cost train 0.55
#             valid set accuracy 61.09%
#             cost valid 0.55
#
# Epoch 14/40:
#             train set accuracy 63.07%
#             cost train 0.53
#             valid set accuracy 62.79%
#             cost valid 0.53
#
# Epoch 15/40:
#             train set accuracy 64.87%
#             cost train 0.51
#             valid set accuracy 64.38%
#             cost valid 0.52
#
# Epoch 16/40:
#             train set accuracy 66.8%
#             cost train 0.5
#             valid set accuracy 66.5%
#             cost valid 0.5
#
# Epoch 17/40:
#             train set accuracy 69.3%
#             cost train 0.48
#             valid set accuracy 68.67%
#             cost valid 0.48
#
# Epoch 18/40:
#             train set accuracy 70.99%
#             cost train 0.46
#             valid set accuracy 70.73%
#             cost valid 0.47
#
# Epoch 19/40:
#             train set accuracy 72.68%
#             cost train 0.45
#             valid set accuracy 72.26%
#             cost valid 0.45
#
# Epoch 20/40:
#             train set accuracy 73.96%
#             cost train 0.44
#             valid set accuracy 73.52%
#             cost valid 0.44
#
# Epoch 21/40:
#             train set accuracy 74.97%
#             cost train 0.42
#             valid set accuracy 74.26%
#             cost valid 0.43
#
# Epoch 22/40:
#             train set accuracy 75.82%
#             cost train 0.41
#             valid set accuracy 75.39%
#             cost valid 0.41
#
# Epoch 23/40:
#             train set accuracy 76.91%
#             cost train 0.4
#             valid set accuracy 76.33%
#             cost valid 0.4
#
# Epoch 24/40:
#             train set accuracy 77.56%
#             cost train 0.38
#             valid set accuracy 77.0%
#             cost valid 0.39
#
# Epoch 25/40:
#             train set accuracy 78.4%
#             cost train 0.37
#             valid set accuracy 77.8%
#             cost valid 0.38
#
# Epoch 26/40:
#             train set accuracy 79.14%
#             cost train 0.36
#             valid set accuracy 78.53%
#             cost valid 0.37
#
# Epoch 27/40:
#             train set accuracy 79.78%
#             cost train 0.35
#             valid set accuracy 79.05%
#             cost valid 0.36
#
# Epoch 28/40:
#             train set accuracy 80.37%
#             cost train 0.34
#             valid set accuracy 79.63%
#             cost valid 0.35
#
# Epoch 29/40:
#             train set accuracy 80.61%
#             cost train 0.33
#             valid set accuracy 79.88%
#             cost valid 0.34
#
# Epoch 30/40:
#             train set accuracy 80.96%
#             cost train 0.33
#             valid set accuracy 80.42%
#             cost valid 0.33
#
# Epoch 31/40:
#             train set accuracy 81.54%
#             cost train 0.32
#             valid set accuracy 80.72%
#             cost valid 0.33
#
# Epoch 32/40:
#             train set accuracy 81.98%
#             cost train 0.31
#             valid set accuracy 81.17%
#             cost valid 0.32
#
# Epoch 33/40:
#             train set accuracy 82.35%
#             cost train 0.3
#             valid set accuracy 81.51%
#             cost valid 0.31
#
# Epoch 34/40:
#             train set accuracy 82.91%
#             cost train 0.3
#             valid set accuracy 81.93%
#             cost valid 0.31
#
# Epoch 35/40:
#             train set accuracy 83.15%
#             cost train 0.29
#             valid set accuracy 82.4%
#             cost valid 0.3
#
# Epoch 36/40:
#             train set accuracy 83.41%
#             cost train 0.29
#             valid set accuracy 82.51%
#             cost valid 0.3
#
# Epoch 37/40:
#             train set accuracy 83.61%
#             cost train 0.28
#             valid set accuracy 82.73%
#             cost valid 0.29
#
# Epoch 38/40:
#             train set accuracy 83.94%
#             cost train 0.28
#             valid set accuracy 83.1%
#             cost valid 0.29
#
# Epoch 39/40:
#             train set accuracy 84.06%
#             cost train 0.27
#             valid set accuracy 83.16%
#             cost valid 0.28
#
# Epoch 40/40:
#             train set accuracy 84.28%
#             cost train 0.27
#             valid set accuracy 83.48%
#             cost valid 0.28

# %%
network = NeuralNetwork([784, 100, 20, 10])
network.learn_with_epochs(training_data, learn_rate=0.01, batch_size=30, epochs=120)
# Out:
# Epoch 1/120:
#             train set accuracy 23.4%
#             cost train 0.87
#             valid set accuracy 22.88%
#             cost valid 0.87
#
# Epoch 2/120:
#             train set accuracy 29.66%
#             cost train 0.83
#             valid set accuracy 29.55%
#             cost valid 0.83
#
# Epoch 3/120:
#             train set accuracy 34.76%
#             cost train 0.8
#             valid set accuracy 34.58%
#             cost valid 0.8
#
# Epoch 4/120:
#             train set accuracy 39.17%
#             cost train 0.77
#             valid set accuracy 39.24%
#             cost valid 0.77
#
# Epoch 5/120:
#             train set accuracy 43.44%
#             cost train 0.74
#             valid set accuracy 43.09%
#             cost valid 0.74
#
# Epoch 6/120:
#             train set accuracy 47.3%
#             cost train 0.71
#             valid set accuracy 46.62%
#             cost valid 0.71
#
# Epoch 7/120:
#             train set accuracy 50.39%
#             cost train 0.68
#             valid set accuracy 49.55%
#             cost valid 0.68
#
# Epoch 8/120:
#             train set accuracy 53.46%
#             cost train 0.65
#             valid set accuracy 52.73%
#             cost valid 0.65
#
# Epoch 9/120:
#             train set accuracy 56.15%
#             cost train 0.62
#             valid set accuracy 55.59%
#             cost valid 0.63
#
# Epoch 10/120:
#             train set accuracy 58.56%
#             cost train 0.6
#             valid set accuracy 57.93%
#             cost valid 0.6
#
# Epoch 11/120:
#             train set accuracy 61.17%
#             cost train 0.57
#             valid set accuracy 60.68%
#             cost valid 0.58
#
# Epoch 12/120:
#             train set accuracy 63.2%
#             cost train 0.55
#             valid set accuracy 62.82%
#             cost valid 0.56
#
# Epoch 13/120:
#             train set accuracy 65.44%
#             cost train 0.53
#             valid set accuracy 64.78%
#             cost valid 0.53
#
# Epoch 14/120:
#             train set accuracy 67.22%
#             cost train 0.51
#             valid set accuracy 66.37%
#             cost valid 0.52
#
# Epoch 15/120:
#             train set accuracy 68.73%
#             cost train 0.49
#             valid set accuracy 67.99%
#             cost valid 0.5
#
# Epoch 16/120:
#             train set accuracy 69.94%
#             cost train 0.48
#             valid set accuracy 69.53%
#             cost valid 0.48
#
# Epoch 17/120:
#             train set accuracy 71.29%
#             cost train 0.46
#             valid set accuracy 70.52%
#             cost valid 0.47
#
# Epoch 18/120:
#             train set accuracy 72.37%
#             cost train 0.45
#             valid set accuracy 71.88%
#             cost valid 0.45
#
# Epoch 19/120:
#             train set accuracy 73.55%
#             cost train 0.43
#             valid set accuracy 72.95%
#             cost valid 0.44
#
# Epoch 20/120:
#             train set accuracy 74.32%
#             cost train 0.42
#             valid set accuracy 73.98%
#             cost valid 0.42
#
# Epoch 21/120:
#             train set accuracy 75.37%
#             cost train 0.41
#             valid set accuracy 74.74%
#             cost valid 0.41
#
# Epoch 22/120:
#             train set accuracy 76.21%
#             cost train 0.4
#             valid set accuracy 75.73%
#             cost valid 0.4
#
# Epoch 23/120:
#             train set accuracy 77.0%
#             cost train 0.39
#             valid set accuracy 76.55%
#             cost valid 0.39
#
# Epoch 24/120:
#             train set accuracy 77.68%
#             cost train 0.38
#             valid set accuracy 77.33%
#             cost valid 0.38
#
# Epoch 25/120:
#             train set accuracy 78.43%
#             cost train 0.37
#             valid set accuracy 78.08%
#             cost valid 0.37
#
# Epoch 26/120:
#             train set accuracy 78.72%
#             cost train 0.36
#             valid set accuracy 78.51%
#             cost valid 0.36
#
# Epoch 27/120:
#             train set accuracy 79.53%
#             cost train 0.35
#             valid set accuracy 79.17%
#             cost valid 0.35
#
# Epoch 28/120:
#             train set accuracy 79.96%
#             cost train 0.34
#             valid set accuracy 79.67%
#             cost valid 0.35
#
# Epoch 29/120:
#             train set accuracy 80.35%
#             cost train 0.33
#             valid set accuracy 80.0%
#             cost valid 0.34
#
# Epoch 30/120:
#             train set accuracy 80.89%
#             cost train 0.33
#             valid set accuracy 80.5%
#             cost valid 0.33
#
# Epoch 31/120:
#             train set accuracy 81.23%
#             cost train 0.32
#             valid set accuracy 80.57%
#             cost valid 0.33
#
# Epoch 32/120:
#             train set accuracy 81.68%
#             cost train 0.31
#             valid set accuracy 81.08%
#             cost valid 0.32
#
# Epoch 33/120:
#             train set accuracy 82.01%
#             cost train 0.31
#             valid set accuracy 81.36%
#             cost valid 0.31
#
# Epoch 34/120:
#             train set accuracy 82.39%
#             cost train 0.3
#             valid set accuracy 81.97%
#             cost valid 0.31
#
# Epoch 35/120:
#             train set accuracy 82.66%
#             cost train 0.3
#             valid set accuracy 82.16%
#             cost valid 0.3
#
# Epoch 36/120:
#             train set accuracy 83.0%
#             cost train 0.29
#             valid set accuracy 82.52%
#             cost valid 0.3
#
# Epoch 37/120:
#             train set accuracy 83.32%
#             cost train 0.29
#             valid set accuracy 82.67%
#             cost valid 0.29
#
# Epoch 38/120:
#             train set accuracy 83.61%
#             cost train 0.28
#             valid set accuracy 82.98%
#             cost valid 0.29
#
# Epoch 39/120:
#             train set accuracy 83.73%
#             cost train 0.28
#             valid set accuracy 83.03%
#             cost valid 0.29
#
# Epoch 40/120:
#             train set accuracy 83.99%
#             cost train 0.27
#             valid set accuracy 83.23%
#             cost valid 0.28
#
# Epoch 41/120:
#             train set accuracy 84.07%
#             cost train 0.27
#             valid set accuracy 83.33%
#             cost valid 0.28
#
# Epoch 42/120:
#             train set accuracy 84.23%
#             cost train 0.27
#             valid set accuracy 83.46%
#             cost valid 0.28
#
# Epoch 43/120:
#             train set accuracy 84.54%
#             cost train 0.26
#             valid set accuracy 84.07%
#             cost valid 0.27
#
# Epoch 44/120:
#             train set accuracy 84.79%
#             cost train 0.26
#             valid set accuracy 84.12%
#             cost valid 0.27
#
# Epoch 45/120:
#             train set accuracy 84.95%
#             cost train 0.26
#             valid set accuracy 84.33%
#             cost valid 0.26
#
# Epoch 46/120:
#             train set accuracy 85.18%
#             cost train 0.25
#             valid set accuracy 84.39%
#             cost valid 0.26
#
# Epoch 47/120:
#             train set accuracy 85.35%
#             cost train 0.25
#             valid set accuracy 84.52%
#             cost valid 0.26
#
# Epoch 48/120:
#             train set accuracy 85.49%
#             cost train 0.25
#             valid set accuracy 84.78%
#             cost valid 0.26
#
# Epoch 49/120:
#             train set accuracy 85.56%
#             cost train 0.24
#             valid set accuracy 84.92%
#             cost valid 0.25
#
# Epoch 50/120:
#             train set accuracy 85.81%
#             cost train 0.24
#             valid set accuracy 84.98%
#             cost valid 0.25
#
# Epoch 51/120:
#             train set accuracy 85.89%
#             cost train 0.24
#             valid set accuracy 85.05%
#             cost valid 0.25
#
# Epoch 52/120:
#             train set accuracy 86.12%
#             cost train 0.24
#             valid set accuracy 85.08%
#             cost valid 0.24
#
# Epoch 53/120:
#             train set accuracy 86.14%
#             cost train 0.23
#             valid set accuracy 85.28%
#             cost valid 0.24
#
# Epoch 54/120:
#             train set accuracy 86.41%
#             cost train 0.23
#             valid set accuracy 85.52%
#             cost valid 0.24
#
# Epoch 55/120:
#             train set accuracy 86.54%
#             cost train 0.23
#             valid set accuracy 85.58%
#             cost valid 0.24
#
# Epoch 56/120:
#             train set accuracy 86.64%
#             cost train 0.23
#             valid set accuracy 85.85%
#             cost valid 0.23
# Epoch 57/120:
#             train set accuracy 86.71%
#             cost train 0.22
#             valid set accuracy 85.77%
#             cost valid 0.24
#
# Epoch 58/120:
#             train set accuracy 86.84%
#             cost train 0.22
#             valid set accuracy 85.86%
#             cost valid 0.23
#
# Epoch 59/120:
#             train set accuracy 86.9%
#             cost train 0.22
#             valid set accuracy 85.88%
#             cost valid 0.23
#
# Epoch 60/120:
#             train set accuracy 87.08%
#             cost train 0.22
#             valid set accuracy 86.04%
#             cost valid 0.23
#
# Epoch 61/120:
#             train set accuracy 87.2%
#             cost train 0.21
#             valid set accuracy 86.23%
#             cost valid 0.23
#
# Epoch 62/120:
#             train set accuracy 87.32%
#             cost train 0.21
#             valid set accuracy 86.08%
#             cost valid 0.22
#
# Epoch 63/120:
#             train set accuracy 87.5%
#             cost train 0.21
#             valid set accuracy 86.29%
#             cost valid 0.22
#
# Epoch 64/120:
#             train set accuracy 87.59%
#             cost train 0.21
#             valid set accuracy 86.49%
#             cost valid 0.22
#
# Epoch 65/120:
#             train set accuracy 87.7%
#             cost train 0.21
#             valid set accuracy 86.52%
#             cost valid 0.22
#
# Epoch 66/120:
#             train set accuracy 87.65%
#             cost train 0.21
#             valid set accuracy 86.7%
#             cost valid 0.22
#
# Epoch 67/120:
#             train set accuracy 87.89%
#             cost train 0.2
#             valid set accuracy 86.76%
#             cost valid 0.22
#
# Epoch 68/120:
#             train set accuracy 87.8%
#             cost train 0.2
#             valid set accuracy 86.7%
#             cost valid 0.22
#
# Epoch 69/120:
#             train set accuracy 87.98%
#             cost train 0.2
#             valid set accuracy 86.68%
#             cost valid 0.21
#
# Epoch 70/120:
#             train set accuracy 88.01%
#             cost train 0.2
#             valid set accuracy 86.92%
#             cost valid 0.21
#
# Epoch 71/120:
#             train set accuracy 87.95%
#             cost train 0.2
#             valid set accuracy 86.88%
#             cost valid 0.21
#
# Epoch 72/120:
#             train set accuracy 88.11%
#             cost train 0.2
#             valid set accuracy 86.96%
#             cost valid 0.21
#
# Epoch 73/120:
#             train set accuracy 88.14%
#             cost train 0.2
#             valid set accuracy 87.11%
#             cost valid 0.21
#
# Epoch 74/120:
#             train set accuracy 88.29%
#             cost train 0.19
#             valid set accuracy 87.13%
#             cost valid 0.21
#
# Epoch 75/120:
#             train set accuracy 88.43%
#             cost train 0.19
#             valid set accuracy 86.93%
#             cost valid 0.21
#
# Epoch 76/120:
#             train set accuracy 88.52%
#             cost train 0.19
#             valid set accuracy 87.18%
#             cost valid 0.2
#
# Epoch 77/120:
#             train set accuracy 88.66%
#             cost train 0.19
#             valid set accuracy 87.46%
#             cost valid 0.2
#
# Epoch 78/120:
#             train set accuracy 88.77%
#             cost train 0.19
#             valid set accuracy 87.62%
#             cost valid 0.2
#
# Epoch 79/120:
#             train set accuracy 88.78%
#             cost train 0.19
#             valid set accuracy 87.78%
#             cost valid 0.2
#
# Epoch 80/120:
#             train set accuracy 88.75%
#             cost train 0.19
#             valid set accuracy 87.72%
#             cost valid 0.2
#
# Epoch 81/120:
#             train set accuracy 88.87%
#             cost train 0.19
#             valid set accuracy 87.9%
#             cost valid 0.2
#
# Epoch 82/120:
#             train set accuracy 88.81%
#             cost train 0.19
#             valid set accuracy 87.65%
#             cost valid 0.2
#
# Epoch 83/120:
#             train set accuracy 88.92%
#             cost train 0.18
#             valid set accuracy 87.84%
#             cost valid 0.2
#
# Epoch 84/120:
#             train set accuracy 89.14%
#             cost train 0.18
#             valid set accuracy 87.99%
#             cost valid 0.19
#
# Epoch 85/120:
#             train set accuracy 89.1%
#             cost train 0.18
#             valid set accuracy 88.12%
#             cost valid 0.19
#
# Epoch 86/120:
#             train set accuracy 89.23%
#             cost train 0.18
#             valid set accuracy 88.02%
#             cost valid 0.19
#
# Epoch 87/120:
#             train set accuracy 89.2%
#             cost train 0.18
#             valid set accuracy 88.18%
#             cost valid 0.19
#
# Epoch 88/120:
#             train set accuracy 89.31%
#             cost train 0.18
#             valid set accuracy 88.21%
#             cost valid 0.19
#
# Epoch 89/120:
#             train set accuracy 89.33%
#             cost train 0.18
#             valid set accuracy 88.02%
#             cost valid 0.19
#
# Epoch 90/120:
#             train set accuracy 89.4%
#             cost train 0.18
#             valid set accuracy 88.31%
#             cost valid 0.19
#
# Epoch 91/120:
#             train set accuracy 89.45%
#             cost train 0.18
#             valid set accuracy 88.03%
#             cost valid 0.19
#
# Epoch 92/120:
#             train set accuracy 89.53%
#             cost train 0.17
#             valid set accuracy 88.21%
#             cost valid 0.19
#
# Epoch 93/120:
#             train set accuracy 89.69%
#             cost train 0.17
#             valid set accuracy 88.45%
#             cost valid 0.19
#
# Epoch 94/120:
#             train set accuracy 89.75%
#             cost train 0.17
#             valid set accuracy 88.25%
#             cost valid 0.19
#
# Epoch 95/120:
#             train set accuracy 89.74%
#             cost train 0.17
#             valid set accuracy 88.33%
#             cost valid 0.18
#
# Epoch 96/120:
#             train set accuracy 89.66%
#             cost train 0.17
#             valid set accuracy 88.4%
#             cost valid 0.18
#
# Epoch 97/120:
#             train set accuracy 89.78%
#             cost train 0.17
#             valid set accuracy 88.52%
#             cost valid 0.18
#
# Epoch 98/120:
#             train set accuracy 89.97%
#             cost train 0.17
#             valid set accuracy 88.72%
#             cost valid 0.18
#
# Epoch 99/120:
#             train set accuracy 89.96%
#             cost train 0.17
#             valid set accuracy 88.62%
#             cost valid 0.18
#
# Epoch 100/120:
#             train set accuracy 90.02%
#             cost train 0.17
#             valid set accuracy 88.86%
#             cost valid 0.18
#
# Epoch 101/120:
#             train set accuracy 89.93%
#             cost train 0.17
#             valid set accuracy 88.87%
#             cost valid 0.18
#
# Epoch 102/120:
#             train set accuracy 89.94%
#             cost train 0.17
#             valid set accuracy 88.63%
#             cost valid 0.18
#
# Epoch 103/120:
#             train set accuracy 89.96%
#             cost train 0.17
#             valid set accuracy 88.96%
#             cost valid 0.18
#
# Epoch 104/120:
#             train set accuracy 90.06%
#             cost train 0.17
#             valid set accuracy 88.67%
#             cost valid 0.18
#
# Epoch 105/120:
#             train set accuracy 90.2%
#             cost train 0.16
#             valid set accuracy 88.72%
#             cost valid 0.18
#
# Epoch 106/120:
#             train set accuracy 90.24%
#             cost train 0.16
#             valid set accuracy 88.88%
#             cost valid 0.18
#
# Epoch 107/120:
#             train set accuracy 90.34%
#             cost train 0.16
#             valid set accuracy 89.02%
#             cost valid 0.18
#
# Epoch 108/120:
#             train set accuracy 90.29%
#             cost train 0.16
#             valid set accuracy 88.98%
#             cost valid 0.18
#
# Epoch 109/120:
#             train set accuracy 90.36%
#             cost train 0.16
#             valid set accuracy 88.73%
#             cost valid 0.18
#
# Epoch 110/120:
#             train set accuracy 90.36%
#             cost train 0.16
#             valid set accuracy 88.97%
#             cost valid 0.17
#
# Epoch 111/120:
#             train set accuracy 90.46%
#             cost train 0.16
#             valid set accuracy 89.03%
#             cost valid 0.17
#
# Epoch 112/120:
#             train set accuracy 90.48%
#             cost train 0.16
#             valid set accuracy 89.03%
#             cost valid 0.17
# Epoch 113/120:
#             train set accuracy 90.54%
#             cost train 0.16
#             valid set accuracy 89.28%
#             cost valid 0.17
#
# Epoch 114/120:
#             train set accuracy 90.65%
#             cost train 0.16
#             valid set accuracy 89.31%
#             cost valid 0.17
#
# Epoch 115/120:
#             train set accuracy 90.55%
#             cost train 0.16
#             valid set accuracy 89.25%
#             cost valid 0.17
#
# Epoch 116/120:
#             train set accuracy 90.63%
#             cost train 0.15
#             valid set accuracy 89.15%
#             cost valid 0.17
#
# Epoch 117/120:
#             train set accuracy 90.6%
#             cost train 0.15
#             valid set accuracy 89.31%
#             cost valid 0.17
#
# Epoch 118/120:
#             train set accuracy 90.74%
#             cost train 0.15
#             valid set accuracy 89.41%
#             cost valid 0.17
#
# Epoch 119/120:
#             train set accuracy 90.77%
#             cost train 0.15
#             valid set accuracy 89.35%
#             cost valid 0.17
#
# Epoch 120/120:
#             train set accuracy 90.74%
#             cost train 0.15
#             valid set accuracy 89.17%
#             cost valid 0.17

# %%
network = NeuralNetwork([784, 100, 100, 100, 10])
network.learn_with_epochs(training_data, learn_rate=0.05, batch_size=30, epochs=120)
# Out:
# Epoch 1/120:
#             train set accuracy 54.83%
#             cost train 0.63
#             valid set accuracy 54.35%
#             cost valid 0.63
#
# Epoch 2/120:
#             train set accuracy 70.07%
#             cost train 0.46
#             valid set accuracy 70.33%
#             cost valid 0.46
#
# Epoch 3/120:
#             train set accuracy 76.05%
#             cost train 0.39
#             valid set accuracy 76.02%
#             cost valid 0.38
#
# Epoch 4/120:
#             train set accuracy 79.05%
#             cost train 0.34
#             valid set accuracy 79.29%
#             cost valid 0.34
#
# Epoch 5/120:
#             train set accuracy 81.4%
#             cost train 0.3
#             valid set accuracy 81.55%
#             cost valid 0.3
#
# Epoch 6/120:
#             train set accuracy 82.16%
#             cost train 0.28
#             valid set accuracy 82.77%
#             cost valid 0.28
#
# Epoch 7/120:
#             train set accuracy 83.45%
#             cost train 0.26
#             valid set accuracy 83.63%
#             cost valid 0.26
#
# Epoch 8/120:
#             train set accuracy 84.86%
#             cost train 0.25
#             valid set accuracy 85.12%
#             cost valid 0.25
#
# Epoch 9/120:
#             train set accuracy 85.24%
#             cost train 0.24
#             valid set accuracy 85.4%
#             cost valid 0.24
#
# Epoch 10/120:
#             train set accuracy 85.52%
#             cost train 0.23
#             valid set accuracy 85.25%
#             cost valid 0.24
#
# Epoch 11/120:
#             train set accuracy 86.33%
#             cost train 0.22
#             valid set accuracy 86.23%
#             cost valid 0.22
#
# Epoch 12/120:
#             train set accuracy 86.33%
#             cost train 0.22
#             valid set accuracy 86.28%
#             cost valid 0.22
#
# Epoch 13/120:
#             train set accuracy 87.06%
#             cost train 0.21
#             valid set accuracy 86.78%
#             cost valid 0.21
#
# Epoch 14/120:
#             train set accuracy 87.35%
#             cost train 0.2
#             valid set accuracy 87.27%
#             cost valid 0.2
#
# Epoch 15/120:
#             train set accuracy 87.64%
#             cost train 0.2
#             valid set accuracy 87.48%
#             cost valid 0.2
#
# Epoch 16/120:
#             train set accuracy 88.23%
#             cost train 0.19
#             valid set accuracy 88.02%
#             cost valid 0.19
#
# Epoch 17/120:
#             train set accuracy 88.3%
#             cost train 0.19
#             valid set accuracy 88.28%
#             cost valid 0.19
#
# Epoch 18/120:
#             train set accuracy 88.46%
#             cost train 0.18
#             valid set accuracy 88.22%
#             cost valid 0.19
#
# Epoch 19/120:
#             train set accuracy 88.08%
#             cost train 0.19
#             valid set accuracy 88.05%
#             cost valid 0.19
#
# Epoch 20/120:
#             train set accuracy 88.42%
#             cost train 0.19
#             valid set accuracy 88.38%
#             cost valid 0.19
#
# Epoch 21/120:
#             train set accuracy 88.39%
#             cost train 0.18
#             valid set accuracy 88.59%
#             cost valid 0.18
#
# Epoch 22/120:
#             train set accuracy 88.48%
#             cost train 0.19
#             valid set accuracy 88.61%
#             cost valid 0.19
#
# Epoch 23/120:
#             train set accuracy 88.57%
#             cost train 0.18
#             valid set accuracy 88.44%
#             cost valid 0.18
#
# Epoch 24/120:
#             train set accuracy 88.64%
#             cost train 0.18
#             valid set accuracy 88.59%
#             cost valid 0.18
#
# Epoch 25/120:
#             train set accuracy 88.84%
#             cost train 0.18
#             valid set accuracy 88.48%
#             cost valid 0.18
#
# Epoch 26/120:
#             train set accuracy 89.26%
#             cost train 0.17
#             valid set accuracy 89.5%
#             cost valid 0.17
#
# Epoch 27/120:
#             train set accuracy 89.11%
#             cost train 0.17
#             valid set accuracy 89.33%
#             cost valid 0.17
#
# Epoch 28/120:
#             train set accuracy 89.68%
#             cost train 0.16
#             valid set accuracy 89.28%
#             cost valid 0.17
#
# Epoch 29/120:
#             train set accuracy 89.96%
#             cost train 0.16
#             valid set accuracy 89.76%
#             cost valid 0.16
#
# Epoch 30/120:
#             train set accuracy 90.05%
#             cost train 0.16
#             valid set accuracy 90.07%
#             cost valid 0.16
#
# Epoch 31/120:
#             train set accuracy 90.16%
#             cost train 0.15
#             valid set accuracy 89.99%
#             cost valid 0.16
#
# Epoch 32/120:
#             train set accuracy 89.77%
#             cost train 0.16
#             valid set accuracy 89.42%
#             cost valid 0.17
#
# Epoch 33/120:
#             train set accuracy 90.03%
#             cost train 0.16
#             valid set accuracy 89.85%
#             cost valid 0.16
#
# Epoch 34/120:
#             train set accuracy 90.28%
#             cost train 0.15
#             valid set accuracy 90.15%
#             cost valid 0.16
#
# Epoch 35/120:
#             train set accuracy 90.48%
#             cost train 0.15
#             valid set accuracy 90.12%
#             cost valid 0.16
#
# Epoch 36/120:
#             train set accuracy 90.48%
#             cost train 0.15
#             valid set accuracy 89.88%
#             cost valid 0.16
#
# Epoch 37/120:
#             train set accuracy 90.59%
#             cost train 0.15
#             valid set accuracy 90.28%
#             cost valid 0.16
#
# Epoch 38/120:
#             train set accuracy 90.9%
#             cost train 0.14
#             valid set accuracy 90.48%
#             cost valid 0.15
#
# Epoch 39/120:
#             train set accuracy 91.15%
#             cost train 0.14
#             valid set accuracy 90.71%
#             cost valid 0.15
#
# Epoch 40/120:
#             train set accuracy 91.5%
#             cost train 0.14
#             valid set accuracy 91.07%
#             cost valid 0.14
#
# Epoch 41/120:
#             train set accuracy 91.36%
#             cost train 0.14
#             valid set accuracy 91.0%
#             cost valid 0.14
#
# Epoch 42/120:
#             train set accuracy 91.03%
#             cost train 0.14
#             valid set accuracy 90.65%
#             cost valid 0.15
#
# Epoch 43/120:
#             train set accuracy 91.21%
#             cost train 0.14
#             valid set accuracy 91.03%
#             cost valid 0.14
#
# Epoch 44/120:
#             train set accuracy 91.19%
#             cost train 0.14
#             valid set accuracy 91.2%
#             cost valid 0.14
#
# Epoch 45/120:
#             train set accuracy 91.49%
#             cost train 0.14
#             valid set accuracy 91.33%
#             cost valid 0.14
#
# Epoch 46/120:
#             train set accuracy 91.47%
#             cost train 0.14
#             valid set accuracy 90.87%
#             cost valid 0.14
#
# Epoch 47/120:
#             train set accuracy 91.82%
#             cost train 0.13
#             valid set accuracy 91.23%
#             cost valid 0.14
#
# Epoch 48/120:
#             train set accuracy 91.69%
#             cost train 0.13
#             valid set accuracy 91.11%
#             cost valid 0.14
#
# Epoch 49/120:
#             train set accuracy 91.99%
#             cost train 0.13
#             valid set accuracy 91.67%
#             cost valid 0.13
#
# Epoch 50/120:
#             train set accuracy 92.14%
#             cost train 0.13
#             valid set accuracy 92.0%
#             cost valid 0.13
#
# Epoch 51/120:
#             train set accuracy 92.2%
#             cost train 0.13
#             valid set accuracy 91.9%
#             cost valid 0.13
#
# Epoch 52/120:
#             train set accuracy 92.12%
#             cost train 0.13
#             valid set accuracy 91.61%
#             cost valid 0.13
#
# Epoch 53/120:
#             train set accuracy 91.8%
#             cost train 0.13
#             valid set accuracy 91.38%
#             cost valid 0.14
#
# Epoch 54/120:
#             train set accuracy 91.75%
#             cost train 0.13
#             valid set accuracy 91.52%
#             cost valid 0.14
#
# Epoch 55/120:
#             train set accuracy 91.84%
#             cost train 0.13
#             valid set accuracy 91.33%
#             cost valid 0.14
#
# Epoch 56/120:
#             train set accuracy 92.06%
#             cost train 0.13
#             valid set accuracy 91.45%
#             cost valid 0.14
# Epoch 57/120:
#             train set accuracy 92.04%
#             cost train 0.13
#             valid set accuracy 91.38%
#             cost valid 0.13
#
# Epoch 58/120:
#             train set accuracy 92.3%
#             cost train 0.12
#             valid set accuracy 91.61%
#             cost valid 0.13
#
# Epoch 59/120:
#             train set accuracy 92.04%
#             cost train 0.13
#             valid set accuracy 91.64%
#             cost valid 0.13
#
# Epoch 60/120:
#             train set accuracy 92.03%
#             cost train 0.13
#             valid set accuracy 91.32%
#             cost valid 0.13
#
# Epoch 61/120:
#             train set accuracy 92.25%
#             cost train 0.12
#             valid set accuracy 92.17%
#             cost valid 0.13
#
# Epoch 62/120:
#             train set accuracy 92.25%
#             cost train 0.12
#             valid set accuracy 92.17%
#             cost valid 0.13
#
# Epoch 63/120:
#             train set accuracy 92.62%
#             cost train 0.12
#             valid set accuracy 92.27%
#             cost valid 0.12
#
# Epoch 64/120:
#             train set accuracy 92.79%
#             cost train 0.12
#             valid set accuracy 92.34%
#             cost valid 0.12
#
# Epoch 65/120:
#             train set accuracy 92.89%
#             cost train 0.11
#             valid set accuracy 92.23%
#             cost valid 0.12
#
# Epoch 66/120:
#             train set accuracy 92.7%
#             cost train 0.12
#             valid set accuracy 92.22%
#             cost valid 0.12
#
# Epoch 67/120:
#             train set accuracy 92.68%
#             cost train 0.12
#             valid set accuracy 92.16%
#             cost valid 0.13
#
# Epoch 68/120:
#             train set accuracy 92.61%
#             cost train 0.12
#             valid set accuracy 92.01%
#             cost valid 0.13
#
# Epoch 69/120:
#             train set accuracy 92.39%
#             cost train 0.12
#             valid set accuracy 92.05%
#             cost valid 0.13
#
# Epoch 70/120:
#             train set accuracy 92.77%
#             cost train 0.12
#             valid set accuracy 92.37%
#             cost valid 0.12
#
# Epoch 71/120:
#             train set accuracy 92.85%
#             cost train 0.12
#             valid set accuracy 92.2%
#             cost valid 0.12
#
# Epoch 72/120:
#             train set accuracy 92.82%
#             cost train 0.12
#             valid set accuracy 91.97%
#             cost valid 0.13
#
# Epoch 73/120:
#             train set accuracy 92.91%
#             cost train 0.12
#             valid set accuracy 92.15%
#             cost valid 0.12
#
# Epoch 74/120:
#             train set accuracy 93.23%
#             cost train 0.11
#             valid set accuracy 92.77%
#             cost valid 0.12
#
# Epoch 75/120:
#             train set accuracy 92.99%
#             cost train 0.11
#             valid set accuracy 92.74%
#             cost valid 0.12
#
# Epoch 76/120:
#             train set accuracy 93.16%
#             cost train 0.11
#             valid set accuracy 92.56%
#             cost valid 0.12
#
# Epoch 77/120:
#             train set accuracy 93.05%
#             cost train 0.11
#             valid set accuracy 92.61%
#             cost valid 0.12
#
# Epoch 78/120:
#             train set accuracy 93.18%
#             cost train 0.11
#             valid set accuracy 92.53%
#             cost valid 0.12
#
# Epoch 79/120:
#             train set accuracy 93.16%
#             cost train 0.11
#             valid set accuracy 92.59%
#             cost valid 0.12
#
# Epoch 80/120:
#             train set accuracy 93.26%
#             cost train 0.11
#             valid set accuracy 92.69%
#             cost valid 0.12
#
# Epoch 81/120:
#             train set accuracy 93.2%
#             cost train 0.11
#             valid set accuracy 92.8%
#             cost valid 0.11
#
# Epoch 82/120:
#             train set accuracy 93.31%
#             cost train 0.11
#             valid set accuracy 92.79%
#             cost valid 0.12
#
# Epoch 83/120:
#             train set accuracy 93.38%
#             cost train 0.11
#             valid set accuracy 93.01%
#             cost valid 0.11
#
# Epoch 84/120:
#             train set accuracy 93.37%
#             cost train 0.11
#             valid set accuracy 92.73%
#             cost valid 0.12
#
# Epoch 85/120:
#             train set accuracy 93.32%
#             cost train 0.11
#             valid set accuracy 92.69%
#             cost valid 0.11
#
# Epoch 86/120:
#             train set accuracy 93.36%
#             cost train 0.11
#             valid set accuracy 92.92%
#             cost valid 0.12
#
# Epoch 87/120:
#             train set accuracy 93.52%
#             cost train 0.11
#             valid set accuracy 93.11%
#             cost valid 0.11
#
# Epoch 88/120:
#             train set accuracy 93.5%
#             cost train 0.1
#             valid set accuracy 92.94%
#             cost valid 0.11
#
# Epoch 89/120:
#             train set accuracy 93.54%
#             cost train 0.1
#             valid set accuracy 93.26%
#             cost valid 0.11
#
# Epoch 90/120:
#             train set accuracy 93.3%
#             cost train 0.11
#             valid set accuracy 92.93%
#             cost valid 0.11
#
# Epoch 91/120:
#             train set accuracy 93.28%
#             cost train 0.11
#             valid set accuracy 92.86%
#             cost valid 0.11
#
# Epoch 92/120:
#             train set accuracy 93.42%
#             cost train 0.11
#             valid set accuracy 92.87%
#             cost valid 0.11
#
# Epoch 93/120:
#             train set accuracy 93.59%
#             cost train 0.1
#             valid set accuracy 93.08%
#             cost valid 0.11
#
# Epoch 94/120:
#             train set accuracy 93.63%
#             cost train 0.1
#             valid set accuracy 93.25%
#             cost valid 0.11
#
# Epoch 95/120:
#             train set accuracy 93.68%
#             cost train 0.1
#             valid set accuracy 93.11%
#             cost valid 0.11
#
# Epoch 96/120:
#             train set accuracy 93.7%
#             cost train 0.1
#             valid set accuracy 93.13%
#             cost valid 0.11
#
# Epoch 97/120:
#             train set accuracy 93.82%
#             cost train 0.1
#             valid set accuracy 93.46%
#             cost valid 0.11
#
# Epoch 98/120:
#             train set accuracy 93.67%
#             cost train 0.1
#             valid set accuracy 93.08%
#             cost valid 0.11
#
# Epoch 99/120:
#             train set accuracy 93.9%
#             cost train 0.1
#             valid set accuracy 93.47%
#             cost valid 0.1
#
# Epoch 100/120:
#             train set accuracy 94.06%
#             cost train 0.1
#             valid set accuracy 93.3%
#             cost valid 0.11
#
# Epoch 101/120:
#             train set accuracy 93.67%
#             cost train 0.1
#             valid set accuracy 93.11%
#             cost valid 0.11
#
# Epoch 102/120:
#             train set accuracy 93.59%
#             cost train 0.1
#             valid set accuracy 93.03%
#             cost valid 0.11
#
# Epoch 103/120:
#             train set accuracy 93.74%
#             cost train 0.1
#             valid set accuracy 93.03%
#             cost valid 0.11
#
# Epoch 104/120:
#             train set accuracy 93.59%
#             cost train 0.1
#             valid set accuracy 93.08%
#             cost valid 0.11
#
# Epoch 105/120:
#             train set accuracy 93.57%
#             cost train 0.1
#             valid set accuracy 93.12%
#             cost valid 0.11
#
# Epoch 106/120:
#             train set accuracy 93.65%
#             cost train 0.1
#             valid set accuracy 93.16%
#             cost valid 0.11
#
# Epoch 107/120:
#             train set accuracy 93.88%
#             cost train 0.1
#             valid set accuracy 93.12%
#             cost valid 0.11
#
# Epoch 108/120:
#             train set accuracy 93.69%
#             cost train 0.1
#             valid set accuracy 93.25%
#             cost valid 0.11
#
# Epoch 109/120:
#             train set accuracy 93.81%
#             cost train 0.1
#             valid set accuracy 93.49%
#             cost valid 0.1
#
# Epoch 110/120:
#             train set accuracy 93.74%
#             cost train 0.1
#             valid set accuracy 93.36%
#             cost valid 0.11
#
# Epoch 111/120:
#             train set accuracy 93.64%
#             cost train 0.1
#             valid set accuracy 93.03%
#             cost valid 0.11
#
# Epoch 112/120:
#             train set accuracy 93.79%
#             cost train 0.1
#             valid set accuracy 93.2%
#             cost valid 0.11
# Epoch 113/120:
#             train set accuracy 93.88%
#             cost train 0.1
#             valid set accuracy 93.26%
#             cost valid 0.11
#
# Epoch 114/120:
#             train set accuracy 93.86%
#             cost train 0.1
#             valid set accuracy 93.33%
#             cost valid 0.11
#
# Epoch 115/120:
#             train set accuracy 93.97%
#             cost train 0.1
#             valid set accuracy 93.28%
#             cost valid 0.11
#
# Epoch 116/120:
#             train set accuracy 93.71%
#             cost train 0.1
#             valid set accuracy 93.19%
#             cost valid 0.11
#
# Epoch 117/120:
#             train set accuracy 93.79%
#             cost train 0.1
#             valid set accuracy 93.33%
#             cost valid 0.11
#
# Epoch 118/120:
#             train set accuracy 93.86%
#             cost train 0.1
#             valid set accuracy 93.45%
#             cost valid 0.11
#
# Epoch 119/120:
#             train set accuracy 93.75%
#             cost train 0.1
#             valid set accuracy 93.29%
#             cost valid 0.11
#
# Epoch 120/120:
#             train set accuracy 93.82%
#             cost train 0.1
#             valid set accuracy 93.03%
#             cost valid 0.11

# %% [markdown]
# ### Wnioski:
# Przetestowaliśmy działanie sieci neuronowych manipulując ich strukturą - liczbą warstw oraz neurownów w każdej z nich, a także zmienialiśmy wartość parametru `learn_rate` i liczbę epok. W rezultacie otrzymywaliśmy różną dokładność rozpoznawania obrazków ze zbioru `MNIST` dla zbioru uczącego i walidacyjnego.
# Z przeprowadzonych eksperymentów możemy stwierdzić że struktura sieci znacząco wpływa na skuteczność działania seci - przykładowo dla 10 neuronów w 1 warstwie ukrytej uzyskaliśmy najgorszą precyzję wynoszącą zaledwie 79%, natomiast dla sieci o 2 warstwach uktytych i 200 neuronach w każdej z nich, lub 3 warstwach ukrytych i 100 neuronach w każdej z nich, dokładność była znacznie wyższa i wynosiła około 91%. Zwiększając rozmiar sieci - liczbę warstw i neuronów, jesteśmy w stanie zwiększyć dokładność sieci, jednak wiąże się to z dłuższym czasem potrzebnym na zbudowanie i wyuczenie sieci. <br><br>
# Kolejnym parametrem który zmienia efektywnosć sieci jest parametr `learn_rate` - mówiący o tym jak szybko sieć ma się uczyć, a tak naprawdę jest to współczynnik proporcjonalności w metodzie gradientu prostego zmieniający długość kroku z jaką przemieszczamy się w kierunku minimum lokalnego. Nie może być on zbyt duży, ponieważ wtedy prawdopodobe są oscylacje wokół minimum, ale nie powienien być także zbyt mały ponieważ możmy nie "zdążyć" zbilżyć się do wartości optymalnej, jednak w połączeniu z dużą liczbą epok, możemy uzyskać bardzo dokładnie minimum lokalne, a tym samym otrzymać bardzo wysoką skuteczność sieci. <br><br>
# Z przeprowadzonych przez nas eksperymentów wyniaka że z rozpoznawainem obrazków ze ziobru MNIST najlepiej radzi sobie sieć o struktorze 3 warst ukrytych i 100 neuronach w każdej z nich i parametrach `learn_rate` = 0.05, `epochs` = 120. Uzyskaliśmy dokładność ok 93,03%. Jednak bardzo dobrze z postawionym zadanie poradziała sobie także nieco mniejsza sieć - 2 warstwy ukryte 100 i 20 neuronów, learn_rate =0,05 oraz `epochs` = 120 uzyskując dokładnośc równą około 92%. Jednak ze względu na jej mniejszą strukturę eksperyment trwał znacznie krócej.
# Wadami sieci neuronowych są z pewnością potrzeba dużej ilości czasu i zasobów obliczeniowych do wytrenowania sieci, a także fakt że za bardzo nie wiemy w jaki sposób sieć dokonuje swoich przewidywań - zdaje się że kolejne warstwy nie reprezentują nie reprezentują nic intuicyjnego.
